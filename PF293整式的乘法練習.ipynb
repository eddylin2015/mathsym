# %% [markdown]
# # 電腦數學符號運算

# %% [markdown]
# ### 第3節. 整式的加乘法練習實作
# 安裝 Python 3.8.7
# - pip install numpy
# - pip install sympy
# - pip install jupyterlab
# - lib.py 自定義函數庫

# %% [markdown]
# 整式的乘法練習
# #開展式子
# f=(x+1)**3 * (x-2)**2
# print("題:")
# display(f)
# ans=sp.expand(f)
# print("解:")
# display(ans)

# %%
import random                                     #亂數 
import math                                       #math 內置數學函數
import numpy as np                                #數字矩陣
import sympy as sp                                #sympy 簡易別名 sp    
from sympy.parsing.sympy_parser import parse_expr #文字字串, 解釋成, Sympy 運算式
from sympy.plotting import plot                   #繪圖表
from IPython.display import Latex,HTML                 #網頁顯示數學符號
import lib                                       #JSON 結構化資料
import re
sp.init_printing("mathjax")                       #sp.init_printing()  168 
def displayTable(NTE):
    tablecontext="<table><tr><td>{}</td></tr>".format("</td><td>".join(_ for _ in ["Qiz","Val","Ans","OK"]))
    for row in NTE:
        St=row["St"]
        Val=row["Val"]
        Ans=row["Ans"]
        OK=row["OK"]
        tablecontext+=f"<tr><td>$${St}$$</td><td>{Val}</td><td>{Ans}</td><td>{OK}</td></tr>"
    tablecontext+="</table>"
    display(HTML(tablecontext)) 
"""
整式的乘法練習
"""
def Get_PF293_Expr(QizAmt):
    sample_list0= list(range(-39,29))   # [-5,-4,-3,-2,-1,1,2,3,4,5]
    sample_list1= list(range(-39,29))
    sample_list1.remove(0)    # 非零數列
    NTE=[]
    for i in range(0,QizAmt):
        a = 1 
        p=random.choice([-5,-4,-3,-2,-1,1,2,3,4,5])
        q=random.choice([-5,-4,-3,-2,-1,1,2,3,4,5])
        b=p+q
        c=p*q
        express_str=f"(x +({a}))* ( x + ({b}))  "  #題型 express_str ax+bx+c
        St=parse_expr(express_str, evaluate=False) #字串解釋為可運算式子 expression
        Val=sp.expand(St)
        TE={}
        TE["St"]=sp.latex(St)
        TE["Val"]=Val  
        TE["Ans"]=""
        TE["OK"]=0
        NTE.append(TE)    
    return NTE

NTE=Get_PF293_Expr(10) 
displayTable(NTE)
# Out:
# <table><tr><td>Qiz</td><td>Val</td><td>Ans</td><td>OK</td></tr><tr><td>$$\left(x + 1\right) \left(x + 4\right)$$</td><td>x**2 + 5*x + 4</td><td></td><td>0</td></tr><tr><td>$$\left(x + 0\right) \left(x + 1\right)$$</td><td>x**2 + x</td><td></td><td>0</td></tr><tr><td>$$\left(x - 5\right) \left(x + 1\right)$$</td><td>x**2 - 4*x - 5</td><td></td><td>0</td></tr><tr><td>$$\left(x - 1\right) \left(x + 1\right)$$</td><td>x**2 - 1</td><td></td><td>0</td></tr><tr><td>$$\left(x - 1\right) \left(x + 1\right)$$</td><td>x**2 - 1</td><td></td><td>0</td></tr><tr><td>$$\left(x + 1\right) \left(x + 6\right)$$</td><td>x**2 + 7*x + 6</td><td></td><td>0</td></tr><tr><td>$$\left(x - 1\right) \left(x + 1\right)$$</td><td>x**2 - 1</td><td></td><td>0</td></tr><tr><td>$$\left(x + 1\right) \left(x + 9\right)$$</td><td>x**2 + 10*x + 9</td><td></td><td>0</td></tr><tr><td>$$\left(x + 1\right) \left(x + 5\right)$$</td><td>x**2 + 6*x + 5</td><td></td><td>0</td></tr><tr><td>$$\left(x - 4\right) \left(x + 1\right)$$</td><td>x**2 - 3*x - 4</td><td></td><td>0</td></tr></table>

# %%
x,y,z=sp.symbols('x,y,z')
NTE=Get_PF293_Expr(4)
for i,TE in enumerate(NTE):
    St=TE["St"]
    Val=TE["Val"]
    print(f"第{i}題:")        
    display(Latex(f" $$ {St} $$ " ))
    ans=input("請作答:")  
    TE["Ans"]=ans
    ans = lib.Text2St(ans)
    if parse_expr(ans).subs({x:7})==Val.subs({x:7}): #比對答案:
        print("答對!")                               #答對加一分
        TE["OK"]=1
    else:                                            #不則
        TE["OK"]=0
        display(Latex(f"答案錯誤, 標準答案: $ {Val} $"))
    
displayTable(NTE)
# Out:
# 第0題:
#  $$ \left(x + 1\right) \left(x + 3\right) $$
# 請作答: x**2+4x+4
# 答案錯誤, 標準答案: $ x**2 + 4*x + 3 $
# 第1題:
#  $$ \left(x + 1\right) \left(x + 8\right) $$
# 請作答: x**2+9x+8
# 答對!
# 第2題:
#  $$ \left(x + 0\right) \left(x + 1\right) $$
# 請作答: 0
# 答案錯誤, 標準答案: $ x**2 + x $
# 第3題:
#  $$ \left(x - 9\right) \left(x + 1\right) $$
# 請作答: 0
# 答案錯誤, 標準答案: $ x**2 - 8*x - 9 $
# <table><tr><td>Qiz</td><td>Val</td><td>Ans</td><td>OK</td></tr><tr><td>$$\left(x + 1\right) \left(x + 3\right)$$</td><td>x**2 + 4*x + 3</td><td>x**2+4x+4</td><td>0</td></tr><tr><td>$$\left(x + 1\right) \left(x + 8\right)$$</td><td>x**2 + 9*x + 8</td><td>x**2+9x+8</td><td>1</td></tr><tr><td>$$\left(x + 0\right) \left(x + 1\right)$$</td><td>x**2 + x</td><td>0</td><td>0</td></tr><tr><td>$$\left(x - 9\right) \left(x + 1\right)$$</td><td>x**2 - 8*x - 9</td><td>0</td><td>0</td></tr></table>

# %%
print("end")
import re
ans ="-9x  ^2+25"
#ans = re.sub(r"(\d)x", r"\1*x", ans)
ans = re.sub(r"X", r"x", ans)
ans = re.sub(r"x[ ]*", r"x", ans)
ans = ans.replace(r"x^", r"x**")

ans
# Out:
# end
# '-9x**2+25'
