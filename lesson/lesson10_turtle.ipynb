# %% [markdown]
# 小海龜
# [ python](https://docs.python.org/3/library/.html)

# %% [markdown]
# python -m demo
# https://mathsolver.microsoft.com/zh-Hant/algebra-calculator
# [trinket.io](https://trinket.io/)
# https://www.teachwithict.com/_tutorial.html
# [小學生講解 螺旋 DEMO](https://www.youtube.com/watch?v=WGQ006oPsNU)

# %%
import sympy as sp
r,a,x=sp.symbols('r,a,x')
r=3*(1-sp.sin(x))
from sympy.plotting import plot
#plot(expr1,(x, -5, 5)) 
#plot(r)

from sympy import *
var('x')
aPlot = plotting.plot_parametric( (x, x**2, (x,0,4)), (3, x, (x,0,16)), (x, 9, (x,0,4)), (.1*cos(x)+3.1, .1*sin(x)+(3.1**2), (x,0,6.5)) )
aPlot[0].line_color='r'
aPlot[1].line_color='g'
aPlot.show()

# %% [markdown]
# ![](https://docs.python.org/3/_images/-star.png)

# %%
import  as agent
agent.color('red', 'yellow')
agent.begin_fill()
while True:
    agent.forward(200)
    agent.left(170)
    if abs(agent.pos()) < 1:
        break
agent.end_fill()
agent.done()

# %% [markdown]
# [angles.pdf](https://www.teachwithict.com/uploads/5/5/8/2/5582303/angles_worksheet_1.pdf)
# ![](https://www.teachwithict.com/uploads/5/5/8/2/5582303/challenge-cards_1.png)
