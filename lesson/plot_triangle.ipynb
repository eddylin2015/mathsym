# %% [markdown]
# # Python, NumPy and MatPlotLib: Plotting Triangles on a Circle to Show the Waveform of sin, cos and tan
#
#  Table of contents
#
# Triangle 1: 3,4,5 Triangle
#
# Trigonometric Identities
#
# Triangle 2: 30,60,90 Degrees Triangle
#
# Triangle 3: Right Angle Isosceles Triangle
#
# Straight Line
#
# Triangle 4: θ=15
#
# Angles from θ=0-45
#
# Angles from θ=45-90
#
# Angles from θ=90-180
#
# Angles from θ=180-270
#
# Angles from θ=270-360
#
# Plotting the sin, cos and tan data
#
# Units of Angles (θ)
#
# Degree
#
# Gradian
#
# Length of an Arc
#
# Radian
#
# Conversion Degrees to Radians
#
# sin, cos and tan
#
# Plotting a Circle

# %% [markdown]
# ## Simple Plot

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

x = range(1,5)
y = [1,4,7,9]
z = [0.5,3,5,10]

plt.plot(x,y, '--dg', linewidth=3)
plt.plot(x,z, 'dm')
plt.title('Test Plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend(['Y', 'Z'])

plt.xlim(0,5)
plt.ylim(0, 12)
plt.show()

# %% [markdown]
# ### 設計直角三角形

# %%
# Perquisites
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

def Plot_RightTriangle():
    plt.close('all')
    # Triangle 1
    x=np.array([0,4,4,0])
    y=np.array([0,0,3,0])
    # Figure and Axes
    fig1=plt.figure(1)
    ax1=fig1.add_subplot(111)
    # Plot Triangle 1 
    ax1.axis('square')
    plt.plot(x,y,color=[0/255,176/255,80/255])
    # Axes Limits
    plt.xlim([-1,7])
    plt.ylim([-1,7])
    # 
    plt.text(0.5,0.25,'θ')
    plt.text(3.5,0.25,'90')
    plt.text(3.5,2.25,'γ')
    plt.text(1.5,-0.5,'Adjacent (A)')
    plt.text(4.5,1.5,'Opposite (O)')
    plt.text(0,2,'Hypotenuse (H)')
    plt.show()

Plot_RightTriangle()
Plot_RightTriangle()
Plot_RightTriangle()

# %% [markdown]
# Triangle 1: 3,4,5 Triangle
# Let's create a plot of a 3,4,5 triangle, starting at the origin [0,0]. The smallest angle of the triangle will begin from the x-axis, thus the corner of the right angle of the triangle will lie on the x-axis. In this case a width of 4 starting so co-ordinate [4,0], we will then reach the furthest point of the triangle, this triangle has a height of 3 so this will be co-ordinate [4,0] and then in order to complete the triangle we need to return to the starting point i.e. the origin [0,0]. These four co-ordinates can be put together in a list i.e.

# %%
# Perquisites
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Triangle 1
x=np.array([0,4,4,0])
y=np.array([0,0,3,0])
# Figure and Axes
fig1=plt.figure(1)
ax1=fig1.add_subplot(111)
# Plot Triangle 1 
ax1.axis('square')
plt.plot(x,y,color=[0/255,176/255,80/255])
# Axes Limits
plt.xlim([-1,7])
plt.ylim([-1,7])
# Grid
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)
# 
plt.text(0.5,0.25,'θ')
plt.text(3.5,0.25,'90')
plt.text(3.5,2.25,'γ')
plt.text(1.5,-0.5,'Adjacent (A)')
plt.text(4.5,1.5,'Opposite (O)')
plt.text(0,2,'Hypotenuse (H)')

# %% [markdown]
# Trigonometric Identities
# The definition of the sine from the perspective of the angle θ is the ratio of the Opposite (O) to the Hypotenuse (H) for the cosine it is the ratio of the Adjacent (A) to the Hypotenuse (H) and for the tangent it is the ratio of the Opposite (O) to the Hypotenuse (H).
#
# \displaystyle \sin \left( \theta \right)=\frac{O}{H}
# \displaystyle \cos \left( \theta \right)=\frac{A}{H}
# \displaystyle \tan \left( \theta \right)=\frac{O}{A}
# For this particular triangle, the so called 3,4,5 triangle:
#
# \displaystyle \sin \left( \theta \right)=\frac{3}{5}
# \displaystyle \cos \left( \theta \right)=\frac{4}{5}
# \displaystyle \tan \left( \theta \right)=\frac{3}{4}
# Simply by definition:
#
# \displaystyle \tan \left( \theta \right)=\frac{O}{A}=\frac{{\left( {\frac{O}{H}} \right)}}{{\left( {\frac{A}{H}} \right)}}=\frac{{\sin \left( \theta \right)}}{{\cos \left( \theta \right)}}=\frac{{\left( {\frac{3}{5}} \right)}}{{\left( {\frac{4}{5}} \right)}}=\frac{3}{4}
# Now if look from the perspective of the angle γ then:
#
# \displaystyle \sin \left( \gamma \right)=\frac{4}{5}
# \displaystyle \cos \left( \gamma \right)=\frac{3}{5}
# \displaystyle \tan \left( \gamma \right)=\frac{4}{3}
# This means:
#
# \displaystyle \sin \left( \gamma \right)=\frac{4}{5}=\cos \left( \theta \right)
# \displaystyle \cos \left( \gamma \right)=\frac{3}{5}=\sin \left( \theta \right)
#
# However the three sides of a triangle add up to 180 degrees. Since we are using a right angle triangle the two other angles must add up to 90 thus:
#
# \displaystyle \gamma =90-\theta
# It then follows:
#
# \displaystyle \cos \left( \theta \right)=\sin \left( {90-\theta } \right)
# \displaystyle \sin \left( \theta \right)=\cos \left( {90-\theta } \right)
# Now  returning to the angle θ we have picked a right angle triangle with the sides O=3, A=4 and H=5. This triangle and all right angle triangles obey Pythagoras theorem:
#
# \displaystyle {{H}^{2}}={{O}^{2}}+{{A}^{2}}
# \displaystyle {{5}^{2}}={{4}^{2}}+{{3}^{2}}
# \displaystyle 25=25
# We can divide through by
#
# \displaystyle {{H}^{2}}
# To get:
#
# \displaystyle \frac{{{{H}^{2}}}}{{{{H}^{2}}}}=\frac{{{{O}^{2}}}}{{{{H}^{2}}}}+\frac{{{{A}^{2}}}}{{{{H}^{2}}}}
# \displaystyle 1={{\sin }^{2}}\left( \theta \right)+{{\cos }^{2}}\left( \theta \right)
# If we plug in our values we can see:
#
# \displaystyle 1={{\left( {\frac{4}{5}} \right)}^{2}}+{{\left( {\frac{3}{5}} \right)}^{2}}
# \displaystyle 1=\frac{16}{{25}}+\frac{{9}}{{25}}
# \displaystyle 1=1
# We can measure these angles using a protractor and find that θ=36.87.
#
# If we normalise by H meaning we divide through by 5, we instead get the side lengths O=4/5, A=3/5 and H=5/5=1.

# %%
# Perquisites
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Data Triangle 1
x=np.array([0,4/5,4/5,0])
y=np.array([0,0,3/5,0])
# Figure and Axes
fig2=plt.figure(1)
ax2=fig2.add_subplot(111)
ax2.axis('square')
# Plot Triangle 1 
plt.plot(x,y,color=[0/255,176/255,80/255])
# Axes
plt.xlim([-0.125,1.125])
plt.ylim([-0.125,1.125])
# Grid
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)

# %% [markdown]
# Triangle 2: 30,60,90 Degrees Triangle
# Another special triangle is the so called 30,60, 90 degrees triangle because each angle is a multiple of 30 degrees.

# %%
# Perquisites
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Triangle 2
x=[0,3**(1/2),3**(1/2),0]
y=[0,0,1,0]
# Figure and Axes
fig1=plt.figure(1)
ax1=fig1.add_subplot(111)
ax1.axis('square')
plt.plot(x,y,'b')
plt.xlim([-1,3])
plt.ylim([-1,3])
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)

# %%
Here:

\displaystyle \theta =30
\displaystyle 90-\theta =60
\displaystyle O=1
\displaystyle A=\sqrt{3}
\displaystyle H=2

We can also plot this by dividing through by H i.e. O=1/2=0.5, A=√3/2, and H=4/2=2.

Let's now plot this alongside the normalised first triangle.

# %%
# Perquisites
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Data Triangle 1
x1=np.array([0,4/5,4/5,0])
y1=np.array([0,0,3/5,0])
# Data Triangle 2
x2=[0,(3**0.5)/2,(3**0.5)/2,0]
y2=[0,0,0.5,0]
# Figure and Axes
fig1=plt.figure(1)
ax1=fig1.add_subplot(111)
ax1.axis('square')
# Plot Triangle 1 
plt.plot(x1,y1,color=[0/255,176/255,80/255])
# Plot Triangle 2
plt.plot(x2,y2,color=[0/255,176/255,240/255])
# Axes Limits
plt.xlim([-0.125,1.125])
plt.ylim([-0.125,1.125])
# Grid
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)

# %% [markdown]
# Triangle 3: Right Angle Isosceles Triangle
# For this right triangle, O and A are equal and we are interested in a normalised triangle so H=1. It therefore follows from Pythagoras Theorem:
#
# \displaystyle {{H}^{2}}={{O}^{2}}+{{A}^{2}}
#
# Since O and A are equal:
#
# \displaystyle {{H}^{2}}=2{{O}^{2}}
# Since H=1:
#
# \displaystyle {{1}^{2}}=2{{O}^{2}}
# Then:
#
# \displaystyle {{O}^{2}}=\frac{1}{2}
# And:
#
# \displaystyle O=\frac{1}{{\sqrt{2}}}=A
# Since the three angles in a triangle add up to 180 degrees and a right angle triangle has a 90 degree angle.
#
# \displaystyle \theta +\gamma +90=180
# \displaystyle \theta +\gamma =90
# It follows that isosceles which has two equal angles:
#
# \displaystyle 2\theta =90
# Then:
#
# \displaystyle \theta =\frac{{90}}{2}
# \displaystyle \theta =45=\gamma
# We can plot this normalised triangle alongside the other two:

# %%
# Perquisites
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Data Triangle 1 θ=36.87
x1=np.array([0,4/5,4/5,0])
y1=np.array([0,0,3/5,0])
# Data Triangle 2 θ=30
x2=[0,(3**0.5)/2,(3**0.5)/2,0]
y2=[0,0,0.5,0]
# Data Triangle 3 θ=45
x3=[0,(1/2**0.5),(1/2**0.5),0]
y3=[0,0,(1/2**0.5),0]
# Figure and Axes
fig1=plt.figure(1)
ax1=fig1.add_subplot(111)
ax1.axis('square')
# Plot Triangle 1 θ=36.87
plt.plot(x1,y1,color=[0/255,176/255,80/255])
# Plot Triangle 2 θ=30
plt.plot(x2,y2,color=[0/255,176/255,240/255])
# Plot Triangle 3 θ=45
plt.plot(x3,y3,color=[112/255,48/255,160/255])
# Axes Limits
plt.xlim([-0.125,1.125])
plt.ylim([-0.125,1.125])
# Grid
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)

# %% [markdown]
# We can actually re-arrange the code so that it the plots are listed from smallest θ to largest θ.

# %% [markdown]
# Straight Line
# We can look at the case when θ=0, in this case γ=180-90-0=90 and when H=1, the adjacent A=H=1 and the opposite O=0.

# %%
# Perquisites
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Line θ=0
x4=[0,1,1,0]
y4=[0,0,0,0]
# Data Triangle 2 θ=30
x2=[0,(3**0.5)/2,(3**0.5)/2,0]
y2=[0,0,0.5,0]
# Data Triangle 1 θ=36.87
x1=np.array([0,4/5,4/5,0])
y1=np.array([0,0,3/5,0])
# Data Triangle 3 θ=45
x3=[0,(1/2**0.5),(1/2**0.5),0]
y3=[0,0,(1/2**0.5),0]
# Figure and Axes
fig1=plt.figure(1)
ax1=fig1.add_subplot(111)
ax1.axis('square')
# Plot Line θ=0
plt.plot(x4,y4,color=[255/255,0/255,0/255])
# Plot Triangle 2 θ=30
plt.plot(x2,y2,color=[0/255,176/255,240/255])
# Plot Triangle 1 θ=36.87
plt.plot(x1,y1,color=[0/255,176/255,80/255])
# Plot Triangle 3 θ=45
plt.plot(x3,y3,color=[112/255,48/255,160/255])
# Axes Limits
plt.xlim([-0.125,1.125])
plt.ylim([-0.125,1.125])
# Grid
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)

# %%
# Perquisites
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Line θ=0
x4=[0,1,1,0]
y4=[0,0,0,0]
# Data Triangle 2 θ=30
x2=[0,(3**0.5)/2,(3**0.5)/2,0]
y2=[0,0,0.5,0]
# Data Triangle 1 θ=36.87
x1=np.array([0,4/5,4/5,0])
y1=np.array([0,0,3/5,0])
# Data Triangle 3 θ=45
x3=[0,(1/2**0.5),(1/2**0.5),0]
y3=[0,0,(1/2**0.5),0]
# Figure and Axes
fig1=plt.figure(1)
ax1=fig1.add_subplot(111)
ax1.axis('square')
""""
# Plot Line θ=0
plt.plot(x4,y4,color=[255/255,0/255,0/255])
plt.scatter(x4[2],y4[2],100,color=[255/255,0/255,0/255])
# Plot Triangle 2 θ=30
plt.plot(x2,y2,color=[0/255,176/255,240/255])
plt.scatter(x2[2],y2[2],100,color=[0/255,176/255,240/255])
# Plot Triangle 1 θ=36.87
plt.plot(x1,y1,color=[0/255,176/255,80/255])
plt.scatter(x1[2],y1[2],100,color=[0/255,176/255,80/255])
# Plot Triangle 3 θ=45
plt.plot(x3,y3,color=[112/255,48/255,160/255])
plt.scatter(x3[2],y3[2],100,color=[112/255,48/255,160/255])
"""
# Axes Limits
plt.xlim([-0.125,1.125])
plt.ylim([-0.125,1.125])
# Grid

plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)

#Arc Plot
d=np.arange(start=0,stop=90,step=1)
rad=np.deg2rad(d)
r=1
xc = r*np.cos(rad)
yc = r*np.sin(rad)
plt.plot(xc,yc,color=[20/255,20/255,20/255],linestyle=':')

# %%
# Perquisites
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Line θ=0
x4=[0,1,1,0]
y4=[0,0,0,0]
# Data Triangle 2 θ=30
x2=[0,(3**0.5)/2,(3**0.5)/2,0]
y2=[0,0,0.5,0]
# Data Triangle 1 θ=36.87
x1=np.array([0,4/5,4/5,0])
y1=np.array([0,0,3/5,0])
# Data Triangle 3 θ=45
x3=[0,(1/2**0.5),(1/2**0.5),0]
y3=[0,0,(1/2**0.5),0]
# Figure and Axes
fig1=plt.figure(1)
ax1=fig1.add_subplot(111)
ax1.axis('square')
# Plot Line θ=0
plt.plot(x4,y4,color=[255/255,0/255,0/255])
plt.scatter(x4[2],y4[2],100,color=[255/255,0/255,0/255])
# Plot Triangle 2 θ=30
plt.plot(x2,y2,color=[0/255,176/255,240/255])
plt.scatter(x2[2],y2[2],100,color=[0/255,176/255,240/255])
# Plot Triangle 1 θ=36.87
plt.plot(x1,y1,color=[0/255,176/255,80/255])
plt.scatter(x1[2],y1[2],100,color=[0/255,176/255,80/255])
# Plot Triangle 3 θ=45
plt.plot(x3,y3,color=[112/255,48/255,160/255])
plt.scatter(x3[2],y3[2],100,color=[112/255,48/255,160/255])
# Axes Limits
plt.xlim([-0.125,1.125])
plt.ylim([-0.125,1.125])
# Grid
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)
#Arc Plot
d=np.arange(start=0,stop=90,step=1)
rad=np.deg2rad(d)
r=1
xc = r*np.cos(rad)
yc = r*np.sin(rad)
plt.plot(xc,yc,color=[20/255,20/255,20/255],linestyle=':')

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Line θ=0
x4=[0,1,1,0]
y4=[0,0,0,0]
# Data Triangle 4 θ=15
x5=[0,0.9659,0.9659,0]
y5=[0,0,0.2588,0]
# Data Triangle 2 θ=30
x2=[0,(3**0.5)/2,(3**0.5)/2,0]
y2=[0,0,0.5,0]
# Data Triangle 1 θ=36.87
#x1=np.array([0,4/5,4/5,0])
#y1=np.array([0,0,3/5,0])
# Data Triangle 3 θ=45
x3=[0,(1/2**0.5),(1/2**0.5),0]
y3=[0,0,(1/2**0.5),0]
# Figure and Axes
fig1=plt.figure(1)
ax1=fig1.add_subplot(111)
ax1.axis('square')
# Plot Line θ=0
plt.plot(x4,y4,color=[255/255,0/255,0/255])
plt.scatter(x4[2],y4[2],100,color=[255/255,0/255,0/255])
# Plot Triangle 4 θ=15
plt.plot(x5,y5,color=[255/255,192/255,0/255])
plt.scatter(x5[2],y5[2],100,color=[255/255,192/255,0/255])
# Plot Triangle 2 θ=30
plt.plot(x2,y2,color=[0/255,176/255,240/255])
plt.scatter(x2[2],y2[2],100,color=[0/255,176/255,240/255])
# Plot Triangle 1 θ=36.87
#plt.plot(x1,y1,color=[0/255,176/255,80/255])
#plt.scatter(x1[2],y1[2],100,color=[0/255,176/255,80/255])
# Plot Triangle 3 θ=45
plt.plot(x3,y3,color=[112/255,48/255,160/255])
plt.scatter(x3[2],y3[2],100,color=[112/255,48/255,160/255])
# Axes Limits
plt.xlim([-0.125,1.125])
plt.ylim([-0.125,1.125])
# Grid
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)
#Arc Plot
d=np.arange(start=0,stop=90,step=1)
rad=np.deg2rad(d)
r=1
xc = r*np.cos(rad)
yc = r*np.sin(rad)
plt.plot(xc,yc,color=[20/255,20/255,20/255],linestyle=':')

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Line θ=0
x4=[0,1,1,0]
y4=[0,0,0,0]
# Data Triangle 4 θ=15
x5=[0,0.9659,0.9659,0]
y5=[0,0,0.2588,0]
# Data Triangle 2 θ=30
x2=[0,(3**0.5)/2,(3**0.5)/2,0]
y2=[0,0,0.5,0]
# Data Triangle 1 θ=36.87
#x1=np.array([0,4/5,4/5,0])
#y1=np.array([0,0,3/5,0])
# Data Triangle 3 θ=45
x3=[0,(1/2**0.5),(1/2**0.5),0]
y3=[0,0,(1/2**0.5),0]
# Figure and Axes
fig1=plt.figure(1)
ax1=fig1.add_subplot(111)
ax1.axis('square')
# Plot Line θ=0
plt.plot(x4,y4,color=[255/255,0/255,0/255])
plt.scatter(x4[2],y4[2],100,color=[255/255,0/255,0/255])
plt.plot(y4,x4,color=[255/255,0/255,0/255])
plt.scatter(y4[2],x4[2],100,color=[255/255,0/255,0/255])
# Plot Triangle 4 θ=15
plt.plot(x5,y5,color=[255/255,192/255,0/255])
plt.scatter(x5[2],y5[2],100,color=[255/255,192/255,0/255])
plt.plot(y5,x5,color=[255/255,192/255,0/255])
plt.scatter(y5[2],x5[2],100,color=[255/255,192/255,0/255])
# Plot Triangle 2 θ=30
plt.plot(x2,y2,color=[0/255,176/255,240/255])
plt.scatter(x2[2],y2[2],100,color=[0/255,176/255,240/255])
plt.plot(y2,x2,color=[0/255,176/255,240/255])
plt.scatter(y2[2],x2[2],100,color=[0/255,176/255,240/255])
# Plot Triangle 1 θ=36.87
#plt.plot(x1,y1,color=[0/255,176/255,80/255])
#plt.scatter(x1[2],y1[2],100,color=[0/255,176/255,80/255])
# Plot Triangle 3 θ=45
plt.plot(x3,y3,color=[112/255,48/255,160/255])
plt.scatter(x3[2],y3[2],100,color=[112/255,48/255,160/255])
plt.plot(y3,x3,color=[112/255,48/255,160/255])
plt.scatter(y3[2],x3[2],100,color=[112/255,48/255,160/255])
# Axes Limits
plt.xlim([-0.125,1.125])
plt.ylim([-0.125,1.125])
# Grid
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)
#Arc Plot
d=np.arange(start=0,stop=90,step=1)
rad=np.deg2rad(d)
r=1
xc = r*np.cos(rad)
yc = r*np.sin(rad)
plt.plot(xc,yc,color=[20/255,20/255,20/255],linestyle=':')

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Line θ=0
x4=[0,1,1,0]
y4=[0,0,0,0]
# Data Triangle 4 θ=15
x5=[0,0.9659,0.9659,0]
y5=[0,0,0.2588,0]
# Data Triangle 2 θ=30
x2=[0,(3**0.5)/2,(3**0.5)/2,0]
y2=[0,0,0.5,0]
# Data Triangle 1 θ=36.87
#x1=np.array([0,4/5,4/5,0])
#y1=np.array([0,0,3/5,0])
# Data Triangle 3 θ=45
x3=[0,(1/2**0.5),(1/2**0.5),0]
y3=[0,0,(1/2**0.5),0]
# Figure and Axes
fig1=plt.figure(1)
ax1=fig1.add_subplot(111)
ax1.axis('square')
# Plot Line θ=0
plt.plot(x4,y4,color=[255/255,0/255,0/255])
plt.scatter(x4[2],y4[2],100,color=[255/255,0/255,0/255])
plt.plot(y4,x4,color=[255/255,0/255,0/255])
plt.scatter(y4[2],x4[2],100,color=[255/255,0/255,0/255])
# Plot Triangle 4 θ=15
plt.plot(x5,y5,color=[255/255,192/255,0/255])
plt.scatter(x5[2],y5[2],100,color=[255/255,192/255,0/255])
plt.plot(y5,x5,color=[255/255,192/255,0/255])
plt.scatter(y5[2],x5[2],100,color=[255/255,192/255,0/255])
# Plot Triangle 2 θ=30
plt.plot(x2,y2,color=[0/255,176/255,240/255])
plt.scatter(x2[2],y2[2],100,color=[0/255,176/255,240/255])
plt.plot(y2,x2,color=[0/255,176/255,240/255])
plt.scatter(y2[2],x2[2],100,color=[0/255,176/255,240/255])
# Plot Triangle 1 θ=36.87
#plt.plot(x1,y1,color=[0/255,176/255,80/255])
#plt.scatter(x1[2],y1[2],100,color=[0/255,176/255,80/255])
# Plot Triangle 3 θ=45
plt.plot(x3,y3,color=[112/255,48/255,160/255])
plt.scatter(x3[2],y3[2],100,color=[112/255,48/255,160/255])
plt.plot(y3,x3,color=[112/255,48/255,160/255])
plt.scatter(y3[2],x3[2],100,color=[112/255,48/255,160/255])
# Axes Limits
plt.xlim([-1.125,1.125])
plt.ylim([-1.125,1.125])
# Grid
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)
#Arc Plot
d=np.arange(start=0,stop=180,step=1)
rad=np.deg2rad(d)
r=1
xc = r*np.cos(rad)
yc = r*np.sin(rad)
plt.plot(xc,yc,color=[20/255,20/255,20/255],linestyle=':')

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Line θ=0
x4=[0,1,1,0]
y4=[0,0,0,0]
# Data Triangle 4 θ=15
x5=[0,0.9659,0.9659,0]
y5=[0,0,0.2588,0]
# Data Triangle 2 θ=30
x2=[0,(3**0.5)/2,(3**0.5)/2,0]
y2=[0,0,0.5,0]
# Data Triangle 1 θ=36.87
#x1=np.array([0,4/5,4/5,0])
#y1=np.array([0,0,3/5,0])
# Data Triangle 3 θ=45
x3=[0,(1/2**0.5),(1/2**0.5),0]
y3=[0,0,(1/2**0.5),0]
# Figure and Axes
fig1=plt.figure(1)
ax1=fig1.add_subplot(111)
ax1.axis('square')
# Plot Line θ=0
plt.plot(x4,y4,color=[255/255,0/255,0/255])
plt.scatter(x4[2],y4[2],100,color=[255/255,0/255,0/255])
plt.plot(y4,x4,color=[255/255,0/255,0/255])
plt.scatter(y4[2],x4[2],100,color=[255/255,0/255,0/255])
plt.plot(np.negative(x4),y4,color=[255/255,0/255,0/255])
plt.scatter(np.negative(x4[2]),y4[2],100,color=[255/255,0/255,0/255])
plt.plot(np.negative(y4),x4,color=[255/255,0/255,0/255])
plt.scatter(np.negative([2]),x4[2],100,color=[255/255,0/255,0/255])
# Plot Triangle 4 θ=15
plt.plot(x5,y5,color=[255/255,192/255,0/255])
plt.scatter(x5[2],y5[2],100,color=[255/255,192/255,0/255])
plt.plot(y5,x5,color=[255/255,192/255,0/255])
plt.scatter(y5[2],x5[2],100,color=[255/255,192/255,0/255])
plt.plot(np.negative(x5),y5,color=[255/255,192/255,0/255])
plt.scatter(np.negative(x5[2]),y5[2],100,color=[255/255,192/255,0/255])
plt.plot(np.negative(y5),x5,color=[255/255,192/255,0/255])
plt.scatter(np.negative(y5[2]),x5[2],100,color=[255/255,192/255,0/255])
# Plot Triangle 2 θ=30
plt.plot(x2,y2,color=[0/255,176/255,240/255])
plt.scatter(x2[2],y2[2],100,color=[0/255,176/255,240/255])
plt.plot(y2,x2,color=[0/255,176/255,240/255])
plt.scatter(y2[2],x2[2],100,color=[0/255,176/255,240/255])
plt.plot(np.negative(x2),y2,color=[0/255,176/255,240/255])
plt.scatter(np.negative(x2[2]),y2[2],100,color=[0/255,176/255,240/255])
plt.plot(np.negative(y2),x2,color=[0/255,176/255,240/255])
plt.scatter(np.negative(y2[2]),x2[2],100,color=[0/255,176/255,240/255])
# Plot Triangle 1 θ=36.87
#plt.plot(x1,y1,color=[0/255,176/255,80/255])
#plt.scatter(x1[2],y1[2],100,color=[0/255,176/255,80/255])
# Plot Triangle 3 θ=45
plt.plot(x3,y3,color=[112/255,48/255,160/255])
plt.scatter(x3[2],y3[2],100,color=[112/255,48/255,160/255])
plt.plot(y3,x3,color=[112/255,48/255,160/255])
plt.scatter(y3[2],x3[2],100,color=[112/255,48/255,160/255])
plt.plot(np.negative(x3),y3,color=[112/255,48/255,160/255])
plt.scatter(np.negative(x3[2]),y3[2],100,color=[112/255,48/255,160/255])
plt.plot(np.negative(y3),x3,color=[112/255,48/255,160/255])
plt.scatter(np.negative(y3[2]),x3[2],100,color=[112/255,48/255,160/255])
# Axes Limits
plt.xlim([-1.125,1.125])
plt.ylim([-1.125,1.125])
# Grid
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)
#Arc Plot
d=np.arange(start=0,stop=180,step=1)
rad=np.deg2rad(d)
r=1
xc = r*np.cos(rad)
yc = r*np.sin(rad)
plt.plot(xc,yc,color=[20/255,20/255,20/255],linestyle=':')

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Line θ=0
x4=[0,1,1,0]
y4=[0,0,0,0]
# Data Triangle 4 θ=15
x5=[0,0.9659,0.9659,0]
y5=[0,0,0.2588,0]
# Data Triangle 2 θ=30
x2=[0,(3**0.5)/2,(3**0.5)/2,0]
y2=[0,0,0.5,0]
# Data Triangle 1 θ=36.87
#x1=np.array([0,4/5,4/5,0])
#y1=np.array([0,0,3/5,0])
# Data Triangle 3 θ=45
x3=[0,(1/2**0.5),(1/2**0.5),0]
y3=[0,0,(1/2**0.5),0]
# Figure and Axes
fig1=plt.figure(1)
ax1=fig1.add_subplot(111)
ax1.axis('square')
# Plot Line θ=0
plt.plot(x4,y4,color=[255/255,0/255,0/255])
plt.scatter(x4[2],y4[2],100,color=[255/255,0/255,0/255])
plt.plot(y4,x4,color=[255/255,0/255,0/255])
plt.scatter(y4[2],x4[2],100,color=[255/255,0/255,0/255])
plt.plot(np.negative(x4),y4,color=[255/255,0/255,0/255])
plt.scatter(np.negative(x4[2]),y4[2],100,color=[255/255,0/255,0/255])
plt.plot(np.negative(y4),x4,color=[255/255,0/255,0/255])
plt.scatter(np.negative([2]),x4[2],100,color=[255/255,0/255,0/255])
# Plot Triangle 4 θ=15
plt.plot(x5,y5,color=[255/255,192/255,0/255])
plt.scatter(x5[2],y5[2],100,color=[255/255,192/255,0/255])
plt.plot(y5,x5,color=[255/255,192/255,0/255])
plt.scatter(y5[2],x5[2],100,color=[255/255,192/255,0/255])
plt.plot(np.negative(x5),y5,color=[255/255,192/255,0/255])
plt.scatter(np.negative(x5[2]),y5[2],100,color=[255/255,192/255,0/255])
plt.plot(np.negative(y5),x5,color=[255/255,192/255,0/255])
plt.scatter(np.negative(y5[2]),x5[2],100,color=[255/255,192/255,0/255])
# Plot Triangle 2 θ=30
plt.plot(x2,y2,color=[0/255,176/255,240/255])
plt.scatter(x2[2],y2[2],100,color=[0/255,176/255,240/255])
plt.plot(y2,x2,color=[0/255,176/255,240/255])
plt.scatter(y2[2],x2[2],100,color=[0/255,176/255,240/255])
plt.plot(np.negative(x2),y2,color=[0/255,176/255,240/255])
plt.scatter(np.negative(x2[2]),y2[2],100,color=[0/255,176/255,240/255])
plt.plot(np.negative(y2),x2,color=[0/255,176/255,240/255])
plt.scatter(np.negative(y2[2]),x2[2],100,color=[0/255,176/255,240/255])
# Plot Triangle 1 θ=36.87
#plt.plot(x1,y1,color=[0/255,176/255,80/255])
#plt.scatter(x1[2],y1[2],100,color=[0/255,176/255,80/255])
# Plot Triangle 3 θ=45
plt.plot(x3,y3,color=[112/255,48/255,160/255])
plt.scatter(x3[2],y3[2],100,color=[112/255,48/255,160/255])
plt.plot(y3,x3,color=[112/255,48/255,160/255])
plt.scatter(y3[2],x3[2],100,color=[112/255,48/255,160/255])
plt.plot(np.negative(x3),y3,color=[112/255,48/255,160/255])
plt.scatter(np.negative(x3[2]),y3[2],100,color=[112/255,48/255,160/255])
plt.plot(np.negative(y3),x3,color=[112/255,48/255,160/255])
plt.scatter(np.negative(y3[2]),x3[2],100,color=[112/255,48/255,160/255])
# Axes Limits
plt.xlim([-1.125,1.125])
plt.ylim([-1.125,1.125])
# Grid
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)
#Arc Plot
d=np.arange(start=0,stop=270,step=1)
rad=np.deg2rad(d)
r=1
xc = r*np.cos(rad)
yc = r*np.sin(rad)
plt.plot(xc,yc,color=[20/255,20/255,20/255],linestyle=':')

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Line θ=0
x4=[0,1,1,0]
y4=[0,0,0,0]
# Data Triangle 4 θ=15
x5=[0,0.9659,0.9659,0]
y5=[0,0,0.2588,0]
# Data Triangle 2 θ=30
x2=[0,(3**0.5)/2,(3**0.5)/2,0]
y2=[0,0,0.5,0]
# Data Triangle 1 θ=36.87
#x1=np.array([0,4/5,4/5,0])
#y1=np.array([0,0,3/5,0])
# Data Triangle 3 θ=45
x3=[0,(1/2**0.5),(1/2**0.5),0]
y3=[0,0,(1/2**0.5),0]
# Figure and Axes
fig1=plt.figure(1)
ax1=fig1.add_subplot(111)
ax1.axis('square')
# Plot Line θ=0
plt.plot(x4,y4,color=[255/255,0/255,0/255])
plt.scatter(x4[2],y4[2],100,color=[255/255,0/255,0/255])
plt.plot(y4,x4,color=[255/255,0/255,0/255])
plt.scatter(y4[2],x4[2],100,color=[255/255,0/255,0/255])
plt.plot(np.negative(x4),y4,color=[255/255,0/255,0/255])
plt.scatter(np.negative(x4[2]),y4[2],100,color=[255/255,0/255,0/255])
plt.plot(np.negative(y4),x4,color=[255/255,0/255,0/255])
plt.scatter(np.negative([2]),x4[2],100,color=[255/255,0/255,0/255])
plt.plot(np.negative(x4),np.negative(y4),color=[255/255,0/255,0/255])
plt.scatter(np.negative(x4[2]),np.negative(y4[2]),100,color=[255/255,0/255,0/255])
plt.plot(np.negative(y4),np.negative(x4),color=[255/255,0/255,0/255])
plt.scatter(np.negative(y4[2]),np.negative(x4[2]),100,color=[255/255,0/255,0/255])
# Plot Triangle 4 θ=15
plt.plot(x5,y5,color=[255/255,192/255,0/255])
plt.scatter(x5[2],y5[2],100,color=[255/255,192/255,0/255])
plt.plot(y5,x5,color=[255/255,192/255,0/255])
plt.scatter(y5[2],x5[2],100,color=[255/255,192/255,0/255])
plt.plot(np.negative(x5),y5,color=[255/255,192/255,0/255])
plt.scatter(np.negative(x5[2]),y5[2],100,color=[255/255,192/255,0/255])
plt.plot(np.negative(y5),x5,color=[255/255,192/255,0/255])
plt.scatter(np.negative(y5[2]),x5[2],100,color=[255/255,192/255,0/255])
plt.plot(np.negative(x5),np.negative(y5),color=[255/255,192/255,0/255])
plt.scatter(np.negative(x5[2]),np.negative(y5[2]),100,color=[255/255,192/255,0/255])
plt.plot(np.negative(y5),np.negative(x5),color=[255/255,192/255,0/255])
plt.scatter(np.negative(y5[2]),np.negative(x5[2]),100,color=[255/255,192/255,0/255])
# Plot Triangle 2 θ=30
plt.plot(x2,y2,color=[0/255,176/255,240/255])
plt.scatter(x2[2],y2[2],100,color=[0/255,176/255,240/255])
plt.plot(y2,x2,color=[0/255,176/255,240/255])
plt.scatter(y2[2],x2[2],100,color=[0/255,176/255,240/255])
plt.plot(np.negative(x2),y2,color=[0/255,176/255,240/255])
plt.scatter(np.negative(x2[2]),y2[2],100,color=[0/255,176/255,240/255])
plt.plot(np.negative(y2),x2,color=[0/255,176/255,240/255])
plt.scatter(np.negative(y2[2]),x2[2],100,color=[0/255,176/255,240/255])
plt.plot(np.negative(x2),np.negative(y2),color=[0/255,176/255,240/255])
plt.scatter(np.negative(x2[2]),np.negative(y2[2]),100,color=[0/255,176/255,240/255])
plt.plot(np.negative(y2),np.negative(x2),color=[0/255,176/255,240/255])
plt.scatter(np.negative(y2[2]),np.negative(x2[2]),100,color=[0/255,176/255,240/255])
# Plot Triangle 1 θ=36.87
#plt.plot(x1,y1,color=[0/255,176/255,80/255])
#plt.scatter(x1[2],y1[2],100,color=[0/255,176/255,80/255])
# Plot Triangle 3 θ=45
plt.plot(x3,y3,color=[112/255,48/255,160/255])
plt.scatter(x3[2],y3[2],100,color=[112/255,48/255,160/255])
plt.plot(y3,x3,color=[112/255,48/255,160/255])
plt.scatter(y3[2],x3[2],100,color=[112/255,48/255,160/255])
plt.plot(np.negative(x3),y3,color=[112/255,48/255,160/255])
plt.scatter(np.negative(x3[2]),y3[2],100,color=[112/255,48/255,160/255])
plt.plot(np.negative(y3),x3,color=[112/255,48/255,160/255])
plt.scatter(np.negative(y3[2]),np.negative(x3[2]),100,color=[112/255,48/255,160/255])
plt.plot(np.negative(x3),np.negative(y3),color=[112/255,48/255,160/255])
plt.scatter(np.negative(x3[2]),np.negative(y3[2]),100,color=[112/255,48/255,160/255])
plt.plot(np.negative(y3),np.negative(x3),color=[112/255,48/255,160/255])
plt.scatter(np.negative(y3[2]),np.negative(x3[2]),100,color=[112/255,48/255,160/255])
# Axes Limits
plt.xlim([-1.125,1.125])
plt.ylim([-1.125,1.125])
# Grid
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)
#Arc Plot
d=np.arange(start=0,stop=270,step=1)
rad=np.deg2rad(d)
r=1
xc = r*np.cos(rad)
yc = r*np.sin(rad)
plt.plot(xc,yc,color=[20/255,20/255,20/255],linestyle=':')

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Line θ=0
x4=[0,1,1,0]
y4=[0,0,0,0]
# Data Triangle 4 θ=15
x5=[0,0.9659,0.9659,0]
y5=[0,0,0.2588,0]
# Data Triangle 2 θ=30
x2=[0,(3**0.5)/2,(3**0.5)/2,0]
y2=[0,0,0.5,0]
# Data Triangle 1 θ=36.87
#x1=np.array([0,4/5,4/5,0])
#y1=np.array([0,0,3/5,0])
# Data Triangle 3 θ=45
x3=[0,(1/2**0.5),(1/2**0.5),0]
y3=[0,0,(1/2**0.5),0]
# Figure and Axes
fig1=plt.figure(1)
ax1=fig1.add_subplot(111)
ax1.axis('square')
# Plot Line θ=0
plt.plot(x4,y4,color=[255/255,0/255,0/255])
plt.scatter(x4[2],y4[2],100,color=[255/255,0/255,0/255])
plt.plot(y4,x4,color=[255/255,0/255,0/255])
plt.scatter(y4[2],x4[2],100,color=[255/255,0/255,0/255])
plt.plot(np.negative(x4),y4,color=[255/255,0/255,0/255])
plt.scatter(np.negative(x4[2]),y4[2],100,color=[255/255,0/255,0/255])
plt.plot(np.negative(y4),x4,color=[255/255,0/255,0/255])
plt.scatter(np.negative([2]),x4[2],100,color=[255/255,0/255,0/255])
plt.plot(np.negative(x4),np.negative(y4),color=[255/255,0/255,0/255])
plt.scatter(np.negative(x4[2]),np.negative(y4[2]),100,color=[255/255,0/255,0/255])
plt.plot(np.negative(y4),np.negative(x4),color=[255/255,0/255,0/255])
plt.scatter(np.negative(y4[2]),np.negative(x4[2]),100,color=[255/255,0/255,0/255])
# Plot Triangle 4 θ=15
plt.plot(x5,y5,color=[255/255,192/255,0/255])
plt.scatter(x5[2],y5[2],100,color=[255/255,192/255,0/255])
plt.plot(y5,x5,color=[255/255,192/255,0/255])
plt.scatter(y5[2],x5[2],100,color=[255/255,192/255,0/255])
plt.plot(np.negative(x5),y5,color=[255/255,192/255,0/255])
plt.scatter(np.negative(x5[2]),y5[2],100,color=[255/255,192/255,0/255])
plt.plot(np.negative(y5),x5,color=[255/255,192/255,0/255])
plt.scatter(np.negative(y5[2]),x5[2],100,color=[255/255,192/255,0/255])
plt.plot(np.negative(x5),np.negative(y5),color=[255/255,192/255,0/255])
plt.scatter(np.negative(x5[2]),np.negative(y5[2]),100,color=[255/255,192/255,0/255])
plt.plot(np.negative(y5),np.negative(x5),color=[255/255,192/255,0/255])
plt.scatter(np.negative(y5[2]),np.negative(x5[2]),100,color=[255/255,192/255,0/255])
# Plot Triangle 2 θ=30
plt.plot(x2,y2,color=[0/255,176/255,240/255])
plt.scatter(x2[2],y2[2],100,color=[0/255,176/255,240/255])
plt.plot(y2,x2,color=[0/255,176/255,240/255])
plt.scatter(y2[2],x2[2],100,color=[0/255,176/255,240/255])
plt.plot(np.negative(x2),y2,color=[0/255,176/255,240/255])
plt.scatter(np.negative(x2[2]),y2[2],100,color=[0/255,176/255,240/255])
plt.plot(np.negative(y2),x2,color=[0/255,176/255,240/255])
plt.scatter(np.negative(y2[2]),x2[2],100,color=[0/255,176/255,240/255])
plt.plot(np.negative(x2),np.negative(y2),color=[0/255,176/255,240/255])
plt.scatter(np.negative(x2[2]),np.negative(y2[2]),100,color=[0/255,176/255,240/255])
plt.plot(np.negative(y2),np.negative(x2),color=[0/255,176/255,240/255])
plt.scatter(np.negative(y2[2]),np.negative(x2[2]),100,color=[0/255,176/255,240/255])
# Plot Triangle 1 θ=36.87
#plt.plot(x1,y1,color=[0/255,176/255,80/255])
#plt.scatter(x1[2],y1[2],100,color=[0/255,176/255,80/255])
# Plot Triangle 3 θ=45
plt.plot(x3,y3,color=[112/255,48/255,160/255])
plt.scatter(x3[2],y3[2],100,color=[112/255,48/255,160/255])
plt.plot(y3,x3,color=[112/255,48/255,160/255])
plt.scatter(y3[2],x3[2],100,color=[112/255,48/255,160/255])
plt.plot(np.negative(x3),y3,color=[112/255,48/255,160/255])
plt.scatter(np.negative(x3[2]),y3[2],100,color=[112/255,48/255,160/255])
plt.plot(np.negative(y3),x3,color=[112/255,48/255,160/255])
plt.scatter(np.negative(y3[2]),np.negative(x3[2]),100,color=[112/255,48/255,160/255])
plt.plot(np.negative(x3),np.negative(y3),color=[112/255,48/255,160/255])
plt.scatter(np.negative(x3[2]),np.negative(y3[2]),100,color=[112/255,48/255,160/255])
plt.plot(np.negative(y3),np.negative(x3),color=[112/255,48/255,160/255])
plt.scatter(np.negative(y3[2]),np.negative(x3[2]),100,color=[112/255,48/255,160/255])
# Axes Limits
plt.xlim([-1.125,1.125])
plt.ylim([-1.125,1.125])
# Grid
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)
#Arc Plot
d=np.arange(start=0,stop=360,step=1)
rad=np.deg2rad(d)
r=1
xc = r*np.cos(rad)
yc = r*np.sin(rad)
plt.plot(xc,yc,color=[20/255,20/255,20/255],linestyle=':')

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Line θ=0
x4=[0,1,1,0]
y4=[0,0,0,0]
# Data Triangle 4 θ=15
x5=[0,0.9659,0.9659,0]
y5=[0,0,0.2588,0]
# Data Triangle 2 θ=30
x2=[0,(3**0.5)/2,(3**0.5)/2,0]
y2=[0,0,0.5,0]
# Data Triangle 1 θ=36.87
#x1=np.array([0,4/5,4/5,0])
#y1=np.array([0,0,3/5,0])
# Data Triangle 3 θ=45
x3=[0,(1/2**0.5),(1/2**0.5),0]
y3=[0,0,(1/2**0.5),0]
# Figure and Axes
fig1=plt.figure(1)
ax1=fig1.add_subplot(111)
ax1.axis('square')
# Plot Line θ=0
plt.plot(x4,y4,color=[255/255,0/255,0/255])
plt.scatter(x4[2],y4[2],100,color=[255/255,0/255,0/255])
plt.plot(y4,x4,color=[255/255,0/255,0/255])
plt.scatter(y4[2],x4[2],100,color=[255/255,0/255,0/255])
plt.plot(np.negative(x4),y4,color=[255/255,0/255,0/255])
plt.scatter(np.negative(x4[2]),y4[2],100,color=[255/255,0/255,0/255])
plt.plot(np.negative(y4),x4,color=[255/255,0/255,0/255])
plt.scatter(np.negative([2]),x4[2],100,color=[255/255,0/255,0/255])
plt.plot(np.negative(x4),np.negative(y4),color=[255/255,0/255,0/255])
plt.scatter(np.negative(x4[2]),np.negative(y4[2]),100,color=[255/255,0/255,0/255])
plt.plot(np.negative(y4),np.negative(x4),color=[255/255,0/255,0/255])
plt.scatter(np.negative(y4[2]),np.negative(x4[2]),100,color=[255/255,0/255,0/255])
plt.plot(x4,np.negative(y4),color=[255/255,0/255,0/255])
plt.scatter(x4[2],np.negative(y4[2]),100,color=[255/255,0/255,0/255])
plt.plot(y4,np.negative(x4),color=[255/255,0/255,0/255])
plt.scatter(y4[2],x4[2],100,color=[255/255,0/255,0/255])
# Plot Triangle 4 θ=15
plt.plot(x5,y5,color=[255/255,192/255,0/255])
plt.scatter(x5[2],y5[2],100,color=[255/255,192/255,0/255])
plt.plot(y5,x5,color=[255/255,192/255,0/255])
plt.scatter(y5[2],x5[2],100,color=[255/255,192/255,0/255])
plt.plot(np.negative(x5),y5,color=[255/255,192/255,0/255])
plt.scatter(np.negative(x5[2]),y5[2],100,color=[255/255,192/255,0/255])
plt.plot(np.negative(y5),x5,color=[255/255,192/255,0/255])
plt.scatter(np.negative(y5[2]),x5[2],100,color=[255/255,192/255,0/255])
plt.plot(np.negative(x5),np.negative(y5),color=[255/255,192/255,0/255])
plt.scatter(np.negative(x5[2]),np.negative(y5[2]),100,color=[255/255,192/255,0/255])
plt.plot(np.negative(y5),np.negative(x5),color=[255/255,192/255,0/255])
plt.scatter(np.negative(y5[2]),np.negative(x5[2]),100,color=[255/255,192/255,0/255])
plt.plot(x5,np.negative(y5),color=[255/255,192/255,0/255])
plt.scatter(x5[2],np.negative(y5[2]),100,color=[255/255,192/255,0/255])
plt.plot(y5,np.negative(x5),color=[255/255,192/255,0/255])
plt.scatter(y5[2],np.negative(x5[2]),100,color=[255/255,192/255,0/255])
# Plot Triangle 2 θ=30
plt.plot(x2,y2,color=[0/255,176/255,240/255])
plt.scatter(x2[2],y2[2],100,color=[0/255,176/255,240/255])
plt.plot(y2,x2,color=[0/255,176/255,240/255])
plt.scatter(y2[2],x2[2],100,color=[0/255,176/255,240/255])
plt.plot(np.negative(x2),y2,color=[0/255,176/255,240/255])
plt.scatter(np.negative(x2[2]),y2[2],100,color=[0/255,176/255,240/255])
plt.plot(np.negative(y2),x2,color=[0/255,176/255,240/255])
plt.scatter(np.negative(y2[2]),x2[2],100,color=[0/255,176/255,240/255])
plt.plot(np.negative(x2),np.negative(y2),color=[0/255,176/255,240/255])
plt.scatter(np.negative(x2[2]),np.negative(y2[2]),100,color=[0/255,176/255,240/255])
plt.plot(np.negative(y2),np.negative(x2),color=[0/255,176/255,240/255])
plt.scatter(np.negative(y2[2]),np.negative(x2[2]),100,color=[0/255,176/255,240/255])
plt.plot(x2,np.negative(y2),color=[0/255,176/255,240/255])
plt.scatter(x2[2],np.negative(y2[2]),100,color=[0/255,176/255,240/255])
plt.plot(y2,np.negative(x2),color=[0/255,176/255,240/255])
plt.scatter(y2[2],np.negative(x2[2]),100,color=[0/255,176/255,240/255])
# Plot Triangle 1 θ=36.87
#plt.plot(x1,y1,color=[0/255,176/255,80/255])
#plt.scatter(x1[2],y1[2],100,color=[0/255,176/255,80/255])
# Plot Triangle 3 θ=45
plt.plot(x3,y3,color=[112/255,48/255,160/255])
plt.scatter(x3[2],y3[2],100,color=[112/255,48/255,160/255])
plt.plot(y3,x3,color=[112/255,48/255,160/255])
plt.scatter(y3[2],x3[2],100,color=[112/255,48/255,160/255])
plt.plot(np.negative(x3),y3,color=[112/255,48/255,160/255])
plt.scatter(np.negative(x3[2]),y3[2],100,color=[112/255,48/255,160/255])
plt.plot(np.negative(y3),x3,color=[112/255,48/255,160/255])
plt.scatter(np.negative(y3[2]),np.negative(x3[2]),100,color=[112/255,48/255,160/255])
plt.plot(np.negative(x3),np.negative(y3),color=[112/255,48/255,160/255])
plt.scatter(np.negative(x3[2]),np.negative(y3[2]),100,color=[112/255,48/255,160/255])
plt.plot(np.negative(y3),np.negative(x3),color=[112/255,48/255,160/255])
plt.scatter(np.negative(y3[2]),np.negative(x3[2]),100,color=[112/255,48/255,160/255])
plt.plot(x3,np.negative(y3),color=[112/255,48/255,160/255])
plt.scatter(x3[2],np.negative(y3[2]),100,color=[112/255,48/255,160/255])
plt.plot(y3,np.negative(x3),color=[112/255,48/255,160/255])
plt.scatter(y3[2],np.negative(x3[2]),100,color=[112/255,48/255,160/255])
# Axes Limits
plt.xlim([-1.125,1.125])
plt.ylim([-1.125,1.125])
# Grid
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)
#Arc Plot
d=np.arange(start=0,stop=360,step=1)
rad=np.deg2rad(d)
r=1
xc = r*np.cos(rad)
yc = r*np.sin(rad)
plt.plot(xc,yc,color=[20/255,20/255,20/255],linestyle=':')

# %%
# Perquisites
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
plt.close('all')
# Data
theta=np.arange(start=0,stop=375,step=15)
O=np.array([0.0000,0.2588,0.5000,0.7071,0.8660,0.9659,1.0000,0.9659,0.8660,0.7071,0.5000,0.2588,0.0000,-0.2588,-0.5000,-0.7071,-0.8660,-0.9659,-1.0000,-0.9659,-0.8660,-0.7071,-0.5000,-0.2588,-0.0000])
A=np.array([1.0000,0.9659,0.8660,0.7071,0.5000,0.2588,0.0000,-0.2588,-0.500,-0.7071,-0.8600,-0.9659,-1.0000,-0.9659,-0.8660,-0.7071,-0.5000,-0.2588,-0.0000,0.2588,0.5000,0.7071,0.8660,0.9659,1.0000])
H=np.ones(len(theta))

# sin plot
plt.figure(2)
plt.scatter(theta,np.divide(O,H),50,color=[255/255,0/255,0/255],label='y=sin(θ)')
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)
plt.xlabel('θ')
plt.ylabel('O/H')
plt.legend()

# cos plot
plt.figure(3)
plt.scatter(theta,np.divide(A,H),50,color=[255/255,0/255,0/255],label='y=cos(θ)')
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)
plt.xlabel('θ')
plt.ylabel('A/H')
plt.legend()

# tan plot
plt.figure(4)
plt.scatter(theta,np.divide(O,A),50,color=[255/255,0/255,0/255],label='y=tan(θ)')
plt.grid(axis='both',which='major',color=[166/255,166/255,166/255], linestyle='-', linewidth=2)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=[166/255,166/255,166/255], linestyle=':', linewidth=1)
plt.xlabel('θ')
plt.ylabel('O/A')
plt.legend()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide

# %%
theta_deg=np.arange(start=0,stop=105,step=15)
theta_rad=np.deg2rad(theta_deg)
O=np.sin(theta_rad)
print(theta_deg)
print(theta_rad)
print(O)
angle_radian=np.deg2rad(angle_degree)
angle_degree=np.rad2deg(angle_radian)
np.sin(angle_radians)
# Out:
# [ 0 15 30 45 60 75 90]
# [0.         0.26179939 0.52359878 0.78539816 1.04719755 1.30899694
#  1.57079633]
# [0.         0.25881905 0.5        0.70710678 0.8660254  0.96592583
#  1.        ]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-c78e4a61027c> in <module>
#       5 print(theta_rad)
#       6 print(O)
# ----> 7 angle_radian=np.deg2rad(angle_degree)
#       8 angle_degree=np.rad2deg(angle_radian)
#       9 np.sin(angle_radians)
#
# NameError: name 'angle_degree' is not defined

# %%
theta_deg=np.arange(start=0,stop=105,step=15)
theta_rad=np.deg2rad(theta_deg)
O=np.sin(theta_rad)
A=np.cos(theta_rad)
O_A=np.divide(O,A)
O_A2=np.tan(theta_rad)
print('theta_deg=')
print(theta_deg)
print('theta_rad=')
print(theta_rad)
print('O=')
print(O)
print('A=')
print(A)
print('O/A=')
print(O_A)
print('tan(θr)=O/A=')
print(O_A2)
# Out:
# theta_deg=
# [ 0 15 30 45 60 75 90]
# theta_rad=
# [0.         0.26179939 0.52359878 0.78539816 1.04719755 1.30899694
#  1.57079633]
# O=
# [0.         0.25881905 0.5        0.70710678 0.8660254  0.96592583
#  1.        ]
# A=
# [1.00000000e+00 9.65925826e-01 8.66025404e-01 7.07106781e-01
#  5.00000000e-01 2.58819045e-01 6.12323400e-17]
# O/A=
# [0.00000000e+00 2.67949192e-01 5.77350269e-01 1.00000000e+00
#  1.73205081e+00 3.73205081e+00 1.63312394e+16]
# tan(θr)=O/A=
# [0.00000000e+00 2.67949192e-01 5.77350269e-01 1.00000000e+00
#  1.73205081e+00 3.73205081e+00 1.63312394e+16]

# %%
#Arc Plot
d=np.arange(start=0,stop=360,step=1)
rad=np.deg2rad(d)
r=1
xc = r*np.cos(rad)
yc = r*np.sin(rad)
plt.plot(xc,yc,color=[20/255,20/255,20/255],linestyle=':')
