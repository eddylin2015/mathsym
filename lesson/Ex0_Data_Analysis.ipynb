# %%
import numpy as np
import pandas as pd
from IPython.display import Latex,HTML,Markdown
def displaySer(sum_s):
    display(Markdown("{}\n{}\n{}".format("|".join(sum_s.index),"|".join("--" for _ in sum_s.index),"|".join(str(v) for i, v in sum_s.items()))))

# %%
import pandas as pd
df=pd.read_excel('data/KW_DATA.xlsx',sheet_name='data',engine='openpyxl',index_col=0)   
df

# %%
df.head()

# %%
import sympy as sp
h=1-sp.sin(sp.pi/3)
d=sp.S(1)/2

# %%
f1=h**2+d**2

# %%
f2=sp.sqrt(f1)

# %%
float(sp.sqrt((1-sp.sin(sp.pi/3))**2+sp.S(1)/2**2))*6

# %%
sp.simplify(f2)

# %%
float(_)

# %%
fns="""右腹股溝韌帶邊緣內側(無重叠)	A內下	A外下	A上下	Ast50pr	Agt50pr	A1	左腹股溝韌帶邊緣左內側(無重叠)	B內下	B外下	B上下	Bst50pr	Bgt50pr	B1	B雙側	B重叠率*	右韌帶下方2CM內側	C內下	C外下	C上下	Cst50pr	Cgt50pr	C1	左韌帶下方2CM內側	D內下	D外下	D上下	Dst50pr	Dgt50pr	D1	D雙側	D重叠率*"""
fns=fns.split("\t")
for fn in fns:
    df1 = df[df[fn]=="X"]
    mean=round(df1["年齡"].mean(),2)
    std=round(df1["年齡"].std(),2)
    cnt=df1.shape[0]
    print(f"{fn}  有{cnt}筆年齡: {mean}+-{std}")
    M_F=df1["性別"].value_counts()
    M=M_F["M"]
    Mr=round(M/cnt,4)
    F=M_F["F"]
    Fr=round(F/cnt,4)
    print(f"{M} {Mr}  {F} {Fr}")
    displaySer(M_F)
    
#print(df1.shape[0])
#df1=  df1=="X" 
#sum_s=df1.sum(axis=0)
#display(sum_s)
#displaySer(sum_s)

# %%
df.dtypes

# %%
count=0
for age in set(df["年齡"]):
    r=df[df["年齡"]==age].shape[0] 
    print(f"{age}  {r}")
    count+=r
print(count)

# %%
df1 = df[df["性別"]=="F"]
print(df1.shape[0])
df1=  df1=="X" 
sum_s=df1.sum(axis=0)
#display(sum_s)
displaySer(sum_s)

# %%
df1 = df[(df["BMI"]>=23) & (df["BMI"]<25)]
print(df1.shape[0])
df1=  df1=="X" 
sum_s=df1.sum(axis=0)
#display(sum_s)
displaySer(sum_s)

# %%
df1 = df[(df["BMI"]>=25) & (df["BMI"]<30)]
print(df1.shape[0])
df1=  df1=="X" 
sum_s=df1.sum(axis=0)
display(sum_s)
#displaySer(sum_s)

# %%
df1 = df[df["BMI"]>=30] 
print(df1.shape[0])
df1=  df1=="X" 
sum_s=df1.sum(axis=0)
display(sum_s)
#displaySer(sum_s)

# %%
df1 = df[(df["年齡"]>=75) & (df["年齡"]<90)]
print(df1.shape[0])
df1=  df1=="X" 
sum_s=df1.sum(axis=0)
display(sum_s)
#displaySer(sum_s)

# %%
df1 = df[df["年齡"]>=90]
print(df1.shape[0])
df1=  df1=="X" 
sum_s=df1.sum(axis=0)
display(sum_s)
#displaySer(sum_s)
