# %%
import datetime
from bs4 import BeautifulSoup
import requests
import re

def txt_title(msg):
    print(msg)
    with open(f"e:/news_title.txt", 'a',encoding='utf-8') as the_file:
        the_file.write(str(msg))
        the_file.write('\n')

news_url=f"http://www.macaodaily.com/html/2020-12/20/node_1.htm"
title_res = requests.get(news_url)
title_res.encoding = "utf-8"
soup = BeautifulSoup(title_res.text, "html.parser")
#links = soup.find_all(["h1","h2","h3","h4","h5"])
links = soup.select("#all_article_list a")
for link in links:
    news_title = link.getText()
    txt_title(news_title)

print("finished .")
# Out:
# A01：廣告
#
# A02：廣告
#
# A03：廣告
#
# A04：廣告
#
# A05：廣告
#
# A06：廣告
#
# A07：廣告
#
# A08：廣告
#
# A09：要聞
# （社論）風雨之後 就是彩虹
# 衛健委：重點人群先打疫苗
# 我疫苗無現嚴重不良反應
# 衛健委：打完疫苗仍要戴口罩
#
# A10：經濟
# 疫苗利好 明年GDP增速反彈五成
# 業界冀明下半年客量復六七成
# 阿里：澳門百店解決電商營運痛點
# 珠澳愛@你全程遊禮啟動
# 綠松石跨境電商峰會日前舉行
# 經濟論文賽  選題聚焦疫情出路
# （一家之言）描畫願景 儲備多元人才
#
# A11：經濟
# 香港上市企私有化交易料加速
# 港IPO集資總額或創十年新高
# 央行規範現金收付 彌合數字鴻溝
# 日美妝百貨融入微信生態
#
# A12：廣告
#
# A13：廣告
#
# A14：廣告
#
# A15：廣告
#
# A16：廣告
#
# B01：澳聞
# 特區授勳抗疫群英
# 特區歡慶回歸廿一周年
# 崔世安：榮譽屬於全澳人士
#
# B02：澳聞
# 三十四個人部門機構受勳
# 二○二○年度澳門特區授勳名單
# 受勳人士機構簡介
#
# B03：要聞
# 中國今明兩年經濟增速約5%
# 中國能量助全球經濟復甦
# 內地明年財策仍取“攻”勢
# 外媒關注中央經濟會議
#
# B04：要聞
# 外商投資安審辦法發佈
# 商務部稱將採必要措施維權
# 內地出台安審辦法釋三信號
# 京兩人染疫一地列中風險
# 黑龍江增兩無症狀者
# 大連增一例本土確診
# 雪景如畫
# 巨餃酬賓
# 超萌小獸醫
#
# B05：澳聞
# 中總：續寫更精彩“澳門故事”
# 工聯：助澳復甦經濟保民生
# 婦聯：應對挑戰繼往開來
# 受勳人士單位：續在崗位發亮
#
# B06：澳聞
# 內地供澳活豬場擴至廿四家
# 做個好公民  學好國旗國歌法
# 青茂完工
# 如何突顯中葡商貿平台優勢？
# 賀一誠：電競助培科技人才
# 楊道匡倡發展綠色金融
#
# B07：澳聞
# 寒潮襲澳昨跌破十度
# 社服店食物籃三百七戶受惠
# 民衆建澳倡外判檢測解滲漏水
# 幾駐澳名譽領事館慶回歸
# 公益金撥十五萬助五人治眼疾
# 平安通籲長者做好禦寒措施
# 黃色寒冷天氣乾燥
# （新聞小語）抗疫擔當 彰顯團結
#
# B08：廣告
#
# B09：廣告
#
# B10：廣告
#
# B11：廣告
#
# B12：要聞
# 美代防長叫停交接
# 前助理：總統可動用軍隊
# 美國會再次通過臨時預算案
# 美擬關閉兩駐俄領事館
#
# C01：體育
# 熱刺“特”圍而出
# 皇馬贏波話咁“伊”
# 曼聯“斯”出名門
# 禾堡“加”分戰
#
# C02：體育
# 聖日門硬闖里爾
# 阿特蘭大惡戰羅馬
# 杜蘭特領籃網擒綠軍
# 蔚山現代亞冠封王
# 曼聯列斯恩怨難斷
# 球壇動態
#
# C03：體育
# 培正A紅藍嵐登頂
# 街舞入奧運利發展
# 跳水賽檢閱疫訓成果
# 尹正力壓群雄捧盃
# 回歸挑戰盃巴西足校奪冠
#
# C04：要聞
# 大陸斥刻意抬升台海熱度
# 台增四輸入新冠病例
# 恐嚇球星
# 學者料綠營選舉將大敗
# 踩街嘉年華
# 藍食安“公投”案過首關
# 藍金門辦黨慶批綠獨裁
#
# C05：澳聞
# 塔石聖誕市集親子同樂
# 善明會訪灣區企業拓視野
# 忘我耍樂
# 長者公寓租金參考市場價
# 文局：細化規劃主題路線
# 江門人社服務澳設點免奔波
# 南網對澳智能供電走廊試運行
#
# C06：澳聞
# 海外僑青高峰論壇譜新篇
# 中山同鄉會書畫賽作品展揭幕
# 青傳協為長者拍攝顯關懷
# 澳鄉親出席五邑大學擴建
# 插畫藝術聯展反思生命
# “他者眼光”藝術展促交流
# 邱天貴見證澳回歸圖展揭幕
# 何潤生冀開拓創新解民困
#
# C07：澳聞
# 廈門聯誼總會雙慶續獻力
# 琴澳青年志願服務基地揭牌
# 街福會新閣就職續服務街坊
# 多措並舉慎防祝融
# 中華文化聯誼青委訪中聯辦
# 穗澳首推醫藥智慧教育
# 南海留學生聯盟赴穗禪考察
# 灣區人資協訪經財司辦
# 童心行動會關愛殘疾者
# 中國書藝會展會員作品
# 禪城聯誼會遊珠海聚鄉情
#
# C08：圖刋
# 丁真熱潮
#
# C09：要聞
# 美五人接種輝瑞疫苗過敏
# 世衛獲近廿億劑新冠疫苗
# 土醫院大火九新冠患者遇難
# 可樂公司裁員逾二千人
# 聯國籲全球合作抗疫
# 斯洛伐克總理確診新冠
# 印度新冠確診逾千萬例
#
# C10：廣告
#
# C11：廣告
#
# C12：要聞
# 月球樣品總重1,731克
# 王毅：中美對抗世界災難
#
# D01：藝海
# 黃榕冀聖誕遇真命天子
# 楊昕與型男拍劇心動
# 任晴佳女大十八變
# 朱千雪帳號破六十萬粉絲
# 林作面試拍戲奉旨睇靚女
# 胡定欣公開兒時舊照
# 祖藍女兒慶生大跳兒童舞
#
# D02：藝海
# 黃奕承認相男人眼光差
# 林志玲增肥備孕
# 小S看《鬼滅之刃》淚崩
# 紀念黃宗英
# 費玉清封咪後低調行善
# “羊城之夏”舉行閉幕文藝晚會
# 新城是非接連而至
# 樂嫂自爆人生最痛
#
# D03：藝海
# 廖國敏：珍惜每場有觀眾音樂會
# 澳視澳門播抗疫紀錄片《無名英雄》
# 奇情多變 奇幻曲折
# 齊聲頌唱慶回歸今續演
# 澳廣視直播回歸升旗儀式
# 新馬路坊會今演出
# 澳門管弦樂團今演出
#
# D04：藝海
# 泰萊斯威特英國創紀錄
# 仙妮亞唐恩借畢彼特抽水
# 新田真劍佑離日回美發展
# Rain自揭追金泰希一年
# 彼特大衛臣被嘲紋身太多
# 姬蒂派斯推超大碼服裝搵銀
# 視事關心
# 澳門電視節目表
#
# D05：廣告
#
# D06：廣告
#
# D07：廣告
#
# D08：廣告
#
# D09：廣告
#
# D10：廣告
#
# D11：廣告
#
# D12：廣告
#
# E01：澳聞
# 海關破三侵權案拘三人
# 警破兩練功券騙案拘兩人
# 外僱涉藉介紹工作呃六千
# 三童休憩區玩火惹官非
# 六旬婦扶手梯跌傷送院
# 如何使用和保護區旗區徽？
# 新聞特搜
# 勞小義賣文創產品疫境救盲
# 在京澳生歌唱賽“粵唱越強”
# 菜農師生歡樂跑慶回歸
# 理工考試加油站為學生打氣
#
# E02：要聞
# 美駐阿基地遭火箭彈襲擊
# 韓經濟乍暖還寒？
# 馬哈蒂爾參加葬禮送慰問
# 國際簡訊
#
# E03：港聞
# 伊院確診者逃離全城通緝
# 港新冠個案突破八千宗
# 港府：爭取兩日內密接者送檢
# 港府：美官員罔顧事實混淆是非
#
# E04：馬經
# 浩勝寶馬潛質不薄
# 頂峰傳奇性能廣泛
# 浩勝皇星態況甚勇
# 安萬堯被拋落馬傷
# 怡昌勇士值得冷敲
# 蘇銘倫今沙田展身手
# 雄龍力謀三連捷
# 美麗傳承 馬王退役
#
# E05：廣告
#
# E06：廣告
#
# E07：廣告
#
# E08：廣告
#
# F01：食經
# 新葡京 歐陸簡約禮品屋
# 喜來登 冬日佳節禮遇
# JW萬豪 齒頰留香味誘人
# 產酒國主釀葡萄
# 聖誕大餐話今昔
# 難忘一年又到尾
# 帝影樓午飯
#
# F02：食經
# 新濠現代觸覺尊尚享受
# 四季留下最難忘回憶
# One & Only中西私房菜
#
# F03：食經
# IKEA咖啡室 大眾“打卡”熱點
# 金麗華 零距離感受歡樂
# 佳景 味遊東瀛西洋
# 自由咖啡 台式麵包 嫁囍禮餅
# 迎尚 新濠鋒 節慶盛宴琳琅滿目
#
# F04：閱讀時間
# 拯救女性的力量
# 願你成為最漂亮的一棵聖誕樹
# 《機智夫妻生活》
# 《破解好萊塢的科幻想像》
# 《未死之人》
# 構建財務自由的收入系統
# 用失敗經歷訴說幸福人生
#
# F05：新園地
# （隨筆）故人與大雁塔
# （老陳海外食事）匠派名物
# （衆藝館）人物  結構 衝突
# （四方聽音）年終盤點
# （山谷小島通信舍）“只有一個學生的學校”
# （胭脂齋）究竟的意識等級
# （時光迴輪）題  外
# （筆雯集）將軍向後轉
# （賭城單身女子周記）平安夜的核心焦慮
#
# F06：廣告
#
# F07：廣告
#
# F08：澳門街
# 直播帶貨做大個餅
# 防疫常態化下首出境
# 小城刊物種類繁多
# 便利行人
# 草原情歌
# finished .

# %%
def tdmrss():
    rssurl=request.args.get("q","https://www.tdm.com.mo/global/xml/livenews_rss.php")
    #the required first parameter of the 'get' method is the 'url':
    print(rssurl)
    x = requests.get(rssurl)
    #print the response text (the content of the requested file):
    return x.text

# %%
def out_docx(mypath,filename,jpeglist):
    from docx import Document
    document = Document()
    document.add_heading('Document Title', 0)
    for f in jpeglist.split(';'):
        pic=f"{mypath}{f}"
        document.add_picture(pic)
    document.save(mypath+filename)


from os import listdir
mypath = "e:/"
files = listdir(mypath)
cate={}
for f in files:
    if ".jpg" in f  and '-' in f:
        key , x =f.split('-');
        if key in cate:
            cate[key]=cate[key] +";"+f
        else:
            cate[key]=f
for k in cate:
    filename =f"{k}.docx"
    print(filename)
    print(cate[k])
    out_docx(mypath,filename,cate[k])
# Out:
# IMG_20210907.docx
# IMG_20210907-204549 (1).jpg;IMG_20210907-204549 (2).jpg;IMG_20210907-204549 (3).jpg

# %%
from docx import Document
from docx.shared import Inches

document = Document()

document.add_heading('Document Title', 0)

p = document.add_paragraph('A plain paragraph having some ')
p.add_run('bold').bold = True
p.add_run(' and some ')
p.add_run('italic.').italic = True

document.add_heading('Heading, level 1', level=1)
document.add_paragraph('Intense quote', style='Intense Quote')

document.add_paragraph(
    'first item in unordered list', style='List Bullet'
)
document.add_paragraph(
    'first item in ordered list', style='List Number'
)

document.add_picture('monty-truth.png', width=Inches(1.25))

records = (
    (3, '101', 'Spam'),
    (7, '422', 'Eggs'),
    (4, '631', 'Spam, spam, eggs, and spam')
)

table = document.add_table(rows=1, cols=3)
hdr_cells = table.rows[0].cells
hdr_cells[0].text = 'Qty'
hdr_cells[1].text = 'Id'
hdr_cells[2].text = 'Desc'
for qty, id, desc in records:
    row_cells = table.add_row().cells
    row_cells[0].text = str(qty)
    row_cells[1].text = id
    row_cells[2].text = desc

document.add_page_break()

document.save('demo.docx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-4b1fcff30dbd> in <module>
# ----> 1 from docx import Document
#       2 from docx.shared import Inches
#       3
#       4 document = Document()
#       5
#
# ModuleNotFoundError: No module named 'docx'

# %%
import numpy as np
import pandas as pd
from IPython.display import Latex,HTML,Markdown
def displaySer(sum_s):
    display(Markdown("{}\n{}\n{}".format("|".join(sum_s.index),"|".join("--" for _ in sum_s.index),"|".join(str(v) for i, v in sum_s.items()))))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-2f141542e9a1> in <module>
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 from IPython.display import Latex,HTML,Markdown
#       4 def displaySer(sum_s):
#       5     display(Markdown("{}\n{}\n{}".format("|".join(sum_s.index),"|".join("--" for _ in sum_s.index),"|".join(str(v) for i, v in sum_s.items()))))
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
df=pd.read_excel('data/KW_DATA.xlsx',sheet_name='data',engine='openpyxl',index_col=0)   
df

# %%
df.head()

# %%
import sympy as sp
h=1-sp.sin(sp.pi/3)
d=sp.S(1)/2

# %%
f1=h**2+d**2

# %%
f2=sp.sqrt(f1)

# %%
float(sp.sqrt((1-sp.sin(sp.pi/3))**2+sp.S(1)/2**2))*6

# %%
sp.simplify(f2)

# %%
float(_)

# %%
fns="""右腹股溝韌帶邊緣內側(無重叠)	A內下	A外下	A上下	Ast50pr	Agt50pr	A1	左腹股溝韌帶邊緣左內側(無重叠)	B內下	B外下	B上下	Bst50pr	Bgt50pr	B1	B雙側	B重叠率*	右韌帶下方2CM內側	C內下	C外下	C上下	Cst50pr	Cgt50pr	C1	左韌帶下方2CM內側	D內下	D外下	D上下	Dst50pr	Dgt50pr	D1	D雙側	D重叠率*"""
fns=fns.split("\t")
for fn in fns:
    df1 = df[df[fn]=="X"]
    mean=round(df1["年齡"].mean(),2)
    std=round(df1["年齡"].std(),2)
    cnt=df1.shape[0]
    print(f"{fn}  有{cnt}筆年齡: {mean}+-{std}")
    M_F=df1["性別"].value_counts()
    M=M_F["M"]
    Mr=round(M/cnt,4)
    F=M_F["F"]
    Fr=round(F/cnt,4)
    print(f"{M} {Mr}  {F} {Fr}")
    displaySer(M_F)
    
#print(df1.shape[0])
#df1=  df1=="X" 
#sum_s=df1.sum(axis=0)
#display(sum_s)
#displaySer(sum_s)

# %%
df.dtypes

# %%
count=0
for age in set(df["年齡"]):
    r=df[df["年齡"]==age].shape[0] 
    print(f"{age}  {r}")
    count+=r
print(count)

# %%
df1 = df[df["性別"]=="F"]
print(df1.shape[0])
df1=  df1=="X" 
sum_s=df1.sum(axis=0)
#display(sum_s)
displaySer(sum_s)

# %%
df1 = df[(df["BMI"]>=23) & (df["BMI"]<25)]
print(df1.shape[0])
df1=  df1=="X" 
sum_s=df1.sum(axis=0)
#display(sum_s)
displaySer(sum_s)

# %%
df1 = df[(df["BMI"]>=25) & (df["BMI"]<30)]
print(df1.shape[0])
df1=  df1=="X" 
sum_s=df1.sum(axis=0)
display(sum_s)
#displaySer(sum_s)

# %%
df1 = df[df["BMI"]>=30] 
print(df1.shape[0])
df1=  df1=="X" 
sum_s=df1.sum(axis=0)
display(sum_s)
#displaySer(sum_s)

# %%
df1 = df[(df["年齡"]>=75) & (df["年齡"]<90)]
print(df1.shape[0])
df1=  df1=="X" 
sum_s=df1.sum(axis=0)
display(sum_s)
#displaySer(sum_s)

# %%
df1 = df[df["年齡"]>=90]
print(df1.shape[0])
df1=  df1=="X" 
sum_s=df1.sum(axis=0)
display(sum_s)
#displaySer(sum_s)
