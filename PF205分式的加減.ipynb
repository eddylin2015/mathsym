# %% [markdown]
# # 電腦數學符號運算

# %% [markdown]
# ### 第3節. 整式的加乘法練習實作
# 安裝 Python 3.8.7
# - pip install numpy
# - pip install sympy
# - pip install jupyterlab
# - lib.py 自定義函數庫
# #### 分式加減
#
# 第1題:
# $$ −\frac{3}{5x^3y^3}−\frac{3}{x^5y^7} $$
#
# 標準答案: -(3*x^2*y^4 + 15)/(5*x^5*y^7)
# $$ \frac{−3x^2y^4+15}{5*x^5y^7}$$

# %%
import numpy as np                                #數字矩陣
import re
import random                                     #亂數 
import math                                       #math 內置數學函數
import sympy as sp                                #sympy 簡易別名 sp    
from sympy.parsing.sympy_parser import parse_expr #文字字串, 解釋成, Sympy 運算式
from IPython.display import Latex,HTML                 #網頁顯示數學符號
sp.init_printing("mathjax")                       #sp.init_printing()  168 
import lib
def displayTable(NTE):
    display(HTML(lib.NTE2HTMLTABLE(NTE))) 
"""
分式加減
"""
def Get_PF205_Expr(QizAmt):
    x,y,z=sp.symbols('x,y,z')
    op_list=["+","-"]
    sample_list0= list(range(1,16))   # [-5,-4,-3,-2,-1,1,2,3,4,5]
    sample_list1= list(range(0,11)) 
    sample_list1.remove(0)    # 非零數列
    NTE=[]
    for i in range(0,QizAmt):
        op= random.choice(op_list)
        a = random.choice( sample_list0 )
        b = random.choice( sample_list0 )
        c = random.choice( sample_list0 )
        d = random.choice( sample_list0 )
        h = random.choice( sample_list1 )
        k = random.choice( sample_list1 )
        h1= random.choice( sample_list1 )
        k1= random.choice( sample_list1 )
        e=lib.lcm(a,b)   
        f=lib.lcm(a,b) // a  
        g=lib.lcm(a,b) // b  
        p=random.choice([-5,-4,-3,-2,-1,1,2,3,4,5])
        q=random.choice([-5,-4,-3,-2,-1,1,2,3,4,5])
        if p+q==0: q=int(math.copysign((abs(q)+2),q))
        b=p+q
        
        c=p*q
        fx1=c / (a*x**h*y**k)
        fx2=d / (b*x**h1*y**k1)
        St=sp.S(0)
        if op=="+":
            St=sp.Add(fx1,fx2)
        if op=="-":
            St=fx1-fx2
        Val=sp.simplify(St)
        TE={}
        TE["St"]=sp.latex(St)
        TE["Val"]=Val        
        TE["Ans"]="-"
        TE["OK"]=0
        TE["ValLatex"]=sp.latex(Val )
        NTE.append(TE)    
    return NTE
if __name__ =="__main__":
    NTE=Get_PF205_Expr(20)
    displayTable(NTE)
# Out:
# <table><tr><td>St</td><td>Val</td><td>Ans</td><td>OK</td></tr><tr><td>$$\frac{10}{x y^{5}} - \frac{2}{7 x^{9} y^{7}}$$</td><td>10/(x*y**5) - 2/(7*x**9*y**7)</td><td>-</td><td>0</td></tr><tr><td>$$- \frac{3}{x^{5} y^{7}} - \frac{2}{x^{7} y^{2}}$$</td><td>-(3*x**2 + 2*y**5)/(x**7*y**7)</td><td>-</td><td>0</td></tr><tr><td>$$- \frac{4}{3 x^{2} y} - \frac{1}{x^{4} y^{4}}$$</td><td>-4/(3*x**2*y) - 1/(x**4*y**4)</td><td>-</td><td>0</td></tr><tr><td>$$- \frac{7}{2 x^{5} y^{3}} - \frac{3}{x^{7} y^{5}}$$</td><td>-(7*x**2*y**2 + 6)/(2*x**7*y**5)</td><td>-</td><td>0</td></tr><tr><td>$$\frac{11}{2 x^{3} y^{3}} - \frac{8}{15 x^{3} y^{7}}$$</td><td>(165*y**4 - 16)/(30*x**3*y**7)</td><td>-</td><td>0</td></tr><tr><td>$$\frac{16}{5 x^{4} y^{8}} + \frac{5}{8 x^{5} y^{7}}$$</td><td>(128*x + 25*y)/(40*x**5*y**8)</td><td>-</td><td>0</td></tr><tr><td>$$\frac{5}{2 x y^{5}} + \frac{7}{6 x^{4} y^{8}}$$</td><td>(15*x**3*y**3 + 7)/(6*x**4*y**8)</td><td>-</td><td>0</td></tr><tr><td>$$\frac{5}{2 x y^{5}}$$</td><td>5/(2*x*y**5)</td><td>-</td><td>0</td></tr><tr><td>$$\frac{3}{14 x^{9} y^{2}} + \frac{11}{4 x^{10} y^{7}}$$</td><td>(6*x*y**5 + 77)/(28*x**10*y**7)</td><td>-</td><td>0</td></tr><tr><td>$$\frac{11}{2 x^{3} y^{4}} - \frac{5}{x^{4} y}$$</td><td>(11*x - 10*y**3)/(2*x**4*y**4)</td><td>-</td><td>0</td></tr><tr><td>$$- \frac{5}{2 x^{10} y^{3}} - \frac{15}{13 x^{10} y^{8}}$$</td><td>-(65*y**5 + 30)/(26*x**10*y**8)</td><td>-</td><td>0</td></tr><tr><td>$$\frac{4}{3 x y^{5}} + \frac{5}{3 x y^{8}}$$</td><td>(4*y**3 + 5)/(3*x*y**8)</td><td>-</td><td>0</td></tr><tr><td>$$\frac{7}{x^{2} y^{5}} + \frac{1}{6 x^{9} y^{7}}$$</td><td>(42*x**7*y**2 + 1)/(6*x**9*y**7)</td><td>-</td><td>0</td></tr><tr><td>$$\frac{4}{x^{8} y^{10}} - \frac{4}{3 x^{9} y^{3}}$$</td><td>4*(3*x - y**7)/(3*x**9*y**10)</td><td>-</td><td>0</td></tr><tr><td>$$\frac{4}{5 x y^{5}} - \frac{7}{6 x^{9} y^{7}}$$</td><td>(24*x**8*y**2 - 35)/(30*x**9*y**7)</td><td>-</td><td>0</td></tr><tr><td>$$\frac{1}{4 x y^{5}} + \frac{13}{2 x^{9} y^{6}}$$</td><td>(x**8*y + 26)/(4*x**9*y**6)</td><td>-</td><td>0</td></tr><tr><td>$$- \frac{5}{x^{4} y^{5}} - \frac{3}{x^{4} y^{8}}$$</td><td>-(5*y**3 + 3)/(x**4*y**8)</td><td>-</td><td>0</td></tr><tr><td>$$\frac{5}{13 x^{2} y^{3}} - \frac{1}{x^{8} y^{5}}$$</td><td>(5*x**6*y**2 - 13)/(13*x**8*y**5)</td><td>-</td><td>0</td></tr><tr><td>$$\frac{25}{14 x^{2} y^{7}} + \frac{6}{5 x^{2} y^{9}}$$</td><td>(125*y**2 + 84)/(70*x**2*y**9)</td><td>-</td><td>0</td></tr><tr><td>$$- \frac{12}{x^{6} y^{9}} - \frac{2}{15 x^{10} y^{6}}$$</td><td>-(180*x**4 + 2*y**3)/(15*x**10*y**9)</td><td>-</td><td>0</td></tr></table>

# %%
"""程式二
分式加減
"""
x,y,z=sp.symbols('x,y,z')
QizAmt=4
Mark=0
NTE=Get_PF205_Expr(QizAmt)
i=0
for TE in NTE:
    i+=1 
    St=TE["St"]
    Val=TE["Val"]
    ValLatex=TE["ValLatex"]
    print(f"第{i}題:")        
    display(Latex(f" $$ {St} $$ " ))
    #display(Latex(f"標準答案: $ {ValLatex} $"))
    #print(Val)
    ans=input("請作答:") 
    ans=lib.Text2St(ans)
    TE["Ans"]=ans
    if parse_expr(ans).subs({x:7})==Val.subs({x:7}):                   #比對答案:
        print("答對!")                              #答對加一分
        Mark+=1
        TE["OK"]=1
    else:                                      #不則
        TE["OK"]=0
        display(Latex(f"答案錯誤, 標準答案: $ {ValLatex} $"))

print(f"總結: 共{QizAmt}題,得 {Mark} 分. ")  #總結得分

displayTable(NTE)
# Out:
# 第1題:
#  $$ - \frac{4}{3 x y^{3}} + \frac{2}{x^{3} y^{7}} $$
# 請作答: 0
# 答案錯誤, 標準答案: $ - \frac{4}{3 x y^{3}} + \frac{2}{x^{3} y^{7}} $
# 第2題:
#  $$ \frac{1}{2 x y^{10}} + \frac{1}{4 x^{3} y^{3}} $$
# 請作答: 0
# 答案錯誤, 標準答案: $ \frac{2 x^{2} + y^{7}}{4 x^{3} y^{10}} $
# 第3題:
#  $$ \frac{3}{x^{4} y^{4}} - \frac{1}{x^{8} y^{9}} $$
# 請作答: 0
# 答案錯誤, 標準答案: $ \frac{3 x^{4} y^{5} - 1}{x^{8} y^{9}} $
# 第4題:
#  $$ \frac{10}{x^{4} y^{3}} - \frac{1}{9 x^{5} y^{3}} $$
# 請作答: 0
# 答案錯誤, 標準答案: $ \frac{90 x - 1}{9 x^{5} y^{3}} $
# 總結: 共4題,得 0 分.
# <table><tr><td>St</td><td>Val</td><td>Ans</td><td>OK</td></tr><tr><td>$$- \frac{4}{3 x y^{3}} + \frac{2}{x^{3} y^{7}}$$</td><td>-4/(3*x*y**3) + 2/(x**3*y**7)</td><td>0</td><td>0</td></tr><tr><td>$$\frac{1}{2 x y^{10}} + \frac{1}{4 x^{3} y^{3}}$$</td><td>(2*x**2 + y**7)/(4*x**3*y**10)</td><td>0</td><td>0</td></tr><tr><td>$$\frac{3}{x^{4} y^{4}} - \frac{1}{x^{8} y^{9}}$$</td><td>(3*x**4*y**5 - 1)/(x**8*y**9)</td><td>0</td><td>0</td></tr><tr><td>$$\frac{10}{x^{4} y^{3}} - \frac{1}{9 x^{5} y^{3}}$$</td><td>(90*x - 1)/(9*x**5*y**3)</td><td>0</td><td>0</td></tr></table>

# %%
print("end")
import re
ans ="-9x  ^2+25"
#ans = re.sub(r"(\d)x", r"\1*x", ans)
ans = re.sub(r"X", r"x", ans)
ans = re.sub(r"x[ ]*", r"x", ans)
ans = ans.replace(r"x^", r"x**")
ans
# Out:
# end
# '-9x**2+25'

# %%
# Out:
# 第1題:
#  $$ - \frac{3}{x^{4} y^{8}} + \frac{7}{x^{5} y^{8}} $$
# 標準答案: $ \frac{7 - 3 x}{x^{5} y^{8}} $
# 第2題:
#  $$ - \frac{2}{x^{3} y^{3}} - \frac{2}{11 x^{10} y^{4}} $$
# 標準答案: $ - \frac{22 x^{7} y + 2}{11 x^{10} y^{4}} $
# 第3題:
#  $$ \frac{5}{6 x y^{9}} - \frac{1}{7 x^{2} y} $$
# 標準答案: $ \frac{35 x - 6 y^{8}}{42 x^{2} y^{9}} $
# 第4題:
#  $$ - \frac{15}{2 x^{9} y^{3}} - \frac{15}{4 x^{9} y^{6}} $$
# 標準答案: $ - \frac{30 y^{3} + 15}{4 x^{9} y^{6}} $
# <table><tr><td>St</td><td>Val</td><td>Ans</td><td>OK</td></tr><tr><td>$$- \frac{3}{x^{4} y^{8}} + \frac{7}{x^{5} y^{8}}$$</td><td>(7 - 3*x)/(x**5*y**8)</td><td>-</td><td>0</td></tr><tr><td>$$- \frac{2}{x^{3} y^{3}} - \frac{2}{11 x^{10} y^{4}}$$</td><td>-(22*x**7*y + 2)/(11*x**10*y**4)</td><td>-</td><td>0</td></tr><tr><td>$$\frac{5}{6 x y^{9}} - \frac{1}{7 x^{2} y}$$</td><td>(35*x - 6*y**8)/(42*x**2*y**9)</td><td>-</td><td>0</td></tr><tr><td>$$- \frac{15}{2 x^{9} y^{3}} - \frac{15}{4 x^{9} y^{6}}$$</td><td>-(30*y**3 + 15)/(4*x**9*y**6)</td><td>-</td><td>0</td></tr></table>
