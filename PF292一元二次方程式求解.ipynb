# %% [markdown]
# # 電腦數學符號運算

# %% [markdown]
# ### 第3節. 一元二次方程式實作
# 安裝 Python 3.8.7
# - pip install numpy
# - pip install sympy
# - pip install jupyterlab
# - lib.py 自定義函數庫

# %%
import random                                     #亂數 
import math                                       #math 內置數學函數
import numpy as np                                #數字矩陣
import sympy as sp                                #sympy 簡易別名 sp    
from sympy.parsing.sympy_parser import parse_expr #文字字串, 解釋成, Sympy 運算式
from sympy.plotting import plot                   #繪圖表
from IPython.display import Latex,HTML                 #網頁顯示數學符號
import json                                       #JSON 結構化資料
sp.init_printing("mathjax")                       #sp.init_printing()  168 
def displayTable(NTE):
    tablecontext="<table><tr><td>{}</td></tr>".format("</td><td>".join(_ for _ in ["Qiz","Val","Ans","OK"]))
    for row in NTE:
        St=row["St"]
        Val=row["Val"]
        Ans=row["Ans"]
        OK=row["OK"]
        tablecontext+=f"<tr><td>$${St}$$</td><td>{Val}</td><td>{Ans}</td><td>{OK}</td></tr>"
    tablecontext+="</table>"
    display(HTML(tablecontext)) 
"""
一元二次方程式 ax^2 + bx +c = 0
"""
def Get_PF292_Expr(QizAmt):
    sample_list0= list(range(-39,29))   # [-5,-4,-3,-2,-1,1,2,3,4,5]
    sample_list1= list(range(-39,29))
    sample_list1.remove(0)    # 非零數列
    NTE=[]
    for i in range(0,QizAmt):
        a = 1 
        p=random.choice([-5,-4,-3,-2,-1,1,2,3,4,5])
        q=random.choice([-5,-4,-3,-2,-1,1,2,3,4,5])
        b=p+q
        c=p*q
        express_str=f"{a}*x**2 + {b}*x +  {c} "  
        St=parse_expr(express_str, evaluate=False)     #字串解釋為可運算式子 expression
        St=sp.Eq(St,0)                              #f(x)=0
        Val=sp.solve(St)                              #因式分解,得出標準答案
        TE={}
        TE["St"]=sp.latex(St)
        TE["Val"]=Val 
        TE["Ans"]=""
        TE["OK"]=0
        NTE.append(TE)    
    return NTE

NTE=Get_PF292_Expr(10)
displayTable(NTE)
# Out:
# <table><tr><td>Qiz</td><td>Val</td><td>Ans</td><td>OK</td></tr><tr><td>$$1 x^{2} + 1 x - 20 = 0$$</td><td>[-5, 4]</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + x \left(-1\right) - 2 = 0$$</td><td>[-1, 2]</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + 10 x + 25 = 0$$</td><td>[-5]</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + 0 x - 4 = 0$$</td><td>[-2, 2]</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + 3 x + 2 = 0$$</td><td>[-2, -1]</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + 7 x + 12 = 0$$</td><td>[-4, -3]</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + 3 x - 10 = 0$$</td><td>[-5, 2]</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + x \left(-6\right) + 8 = 0$$</td><td>[2, 4]</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + x \left(-3\right) - 10 = 0$$</td><td>[-2, 5]</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + 6 x + 9 = 0$$</td><td>[-3]</td><td></td><td>0</td></tr></table>

# %%
NTE=Get_PF292_Expr(4)
for i,TE in enumerate(NTE):
    St=TE["St"]
    Val=TE["Val"]
    print(f"第{i}題:")        
    display(Latex(f" $$ {St} $$ " ))
    ans=[]
    for idx in range(0,len(Val)):
        ans1=input(f"請作答x{idx+1}:")  
        ans.append(int(ans1))
    TE["Ans"]=ans
    if ans==Val:                   #比對答案:
        print("答對!")                              #答對加一分
        TE["OK"]=1
    else:                                      #不則
        TE["OK"]=0
        display(Latex(f"答案錯誤, 標準答案: $ {Val} $"))
    
displayTable(NTE)
# Out:
# 第0題:
#  $$ 1 x^{2} + x \left(-1\right) - 6 = 0 $$
# 請作答x1: 0
# 請作答x2: 0
# 答案錯誤, 標準答案: $ [-2, 3] $
# 第1題:
#  $$ 1 x^{2} + 2 x - 3 = 0 $$
# 請作答x1: 0
# 請作答x2: 0
# 答案錯誤, 標準答案: $ [-3, 1] $
# 第2題:
#  $$ 1 x^{2} + 5 x + 4 = 0 $$
# 請作答x1: 0
# 請作答x2: 0
# 答案錯誤, 標準答案: $ [-4, -1] $
# 第3題:
#  $$ 1 x^{2} + 3 x - 10 = 0 $$
# 請作答x1: 0
# 請作答x2: 0
# 答案錯誤, 標準答案: $ [-5, 2] $
# <table><tr><td>Qiz</td><td>Val</td><td>Ans</td><td>OK</td></tr><tr><td>$$1 x^{2} + x \left(-1\right) - 6 = 0$$</td><td>[-2, 3]</td><td>[0, 0]</td><td>0</td></tr><tr><td>$$1 x^{2} + 2 x - 3 = 0$$</td><td>[-3, 1]</td><td>[0, 0]</td><td>0</td></tr><tr><td>$$1 x^{2} + 5 x + 4 = 0$$</td><td>[-4, -1]</td><td>[0, 0]</td><td>0</td></tr><tr><td>$$1 x^{2} + 3 x - 10 = 0$$</td><td>[-5, 2]</td><td>[0, 0]</td><td>0</td></tr></table>

# %%
print("end")
# Out:
# end
