# %% [markdown]
# # 電腦數學符號運算

# %% [markdown]
# ### 第3節. 整式的乘法公式法平方差練習實作
# 安裝 Python 3.8.7
# - pip install numpy
# - pip install sympy
# - pip install jupyterlab
# - lib.py 自定義函數庫

# %% [markdown]
# 整式的乘法公式
# 平方差公式
# (px+qy)(px-qy)= ax^2-by^2, a=p2, b=q2

# %%
import random                                     #亂數 
import math                                       #math 內置數學函數
import numpy as np                                #數字矩陣
import sympy as sp                                #sympy 簡易別名 sp    
from sympy.parsing.sympy_parser import parse_expr #文字字串, 解釋成, Sympy 運算式
from IPython.display import Latex,HTML,Markdown                 #網頁顯示數學符號
import re
import lib
from lib import GetTE
sp.init_printing("mathjax")                       #sp.init_printing()  168 
def displayTable(NTE):
    display(Markdown(lib.NTE2TBL(NTE))) 
"""
整式的乘法公式完全平方公式 題型1  
"""   
def Get_PF2021_Expr(QN):
    x,y,z=sp.symbols('x y z')
    NTE=[]
    for idx in range(0,QN):
        p,q=np.random.choice(range(-16,16),2)
        p=p if p!=0 else 1;q=q if q!=0 else 1
        Tidx=idx % 3
        if Tidx==0:
            express_str=f"(x+({q})) ** 2" 
            St=parse_expr(express_str, evaluate=False) 
            Stt=sp.latex(St)
        elif Tidx==1:
            Stt=f"({p}+y)^2"
            St=(p+y)**2
        elif Tidx==2:
            Stt=f"({p}-y)^2"
            St=(p-y)**2
        Val=sp.expand(St)
        TE=GetTE(idx,Stt,Val)        
        NTE.append(TE)    
    return NTE

if __name__=="__main__":
    NTE=Get_PF2021_Expr(10)
    displayTable(NTE)
# Out:
# 號|題|值|答|檢查|題型|提示
# --|--|--|--|--|--|--
# 0|$$\left(x + 8\right)^{2}$$|x**2 + 16*x + 64||0|-1||0
# 1|$$(-9+y)^2$$|y**2 - 18*y + 81||0|-1||0
# 2|$$(-2-y)^2$$|y**2 + 4*y + 4||0|-1||0
# 3|$$\left(x + 10\right)^{2}$$|x**2 + 20*x + 100||0|-1||0
# 4|$$(-15+y)^2$$|y**2 - 30*y + 225||0|-1||0
# 5|$$(-5-y)^2$$|y**2 + 10*y + 25||0|-1||0
# 6|$$\left(x - 2\right)^{2}$$|x**2 - 4*x + 4||0|-1||0
# 7|$$(-13+y)^2$$|y**2 - 26*y + 169||0|-1||0
# 8|$$(12-y)^2$$|y**2 - 24*y + 144||0|-1||0
# 9|$$\left(x - 12\right)^{2}$$|x**2 - 24*x + 144||0|-1||0

# %%
import random                                     #亂數 
import math                                       #math 內置數學函數
import numpy as np                                #數字矩陣
import sympy as sp                                #sympy 簡易別名 sp    
from sympy.parsing.sympy_parser import parse_expr #文字字串, 解釋成, Sympy 運算式
from IPython.display import Latex,HTML,Markdown                 #網頁顯示數學符號
import re
import lib
from lib import GetTE
sp.init_printing("mathjax")                       #sp.init_printing()  168 
def displayTable(NTE):
    display(Markdown(lib.NTE2TBL(NTE))) 
"""
整式的乘法公式完全平方公式 題型2  
"""   
def Get_PF2021_Expr(QN):
    x,y,z=sp.symbols('x y z')
    NTE=[]
    for idx in range(0,QN):
        p,q=np.random.choice(range(-16,16),2)
        p=p if p!=0 else 1;q=q if q!=0 else 1
        Tidx=idx % 3
        if Tidx==0:
            express_str=f"({p}*x+({q})) ** 2" 
            St=parse_expr(express_str, evaluate=False) 
            Stt=sp.latex(St)
        elif Tidx==1:
            St=(p+q*y)**2
            Stt=sp.latex(St)
        elif Tidx==2:
            St=(p*x+q*y)**2
            Stt=sp.latex(St)
        Val=sp.expand(St)
        TE=GetTE(idx,Stt,Val)        
        NTE.append(TE)    
    return NTE

if __name__=="__main__":
    NTE=Get_PF2021_Expr(10)
    displayTable(NTE)
# Out:
# 號|題|值|答|檢查|題型|提示
# --|--|--|--|--|--|--
# 0|$$\left(3 x - 12\right)^{2}$$|9*x**2 - 72*x + 144||0|-1||0
# 1|$$\left(8 y + 10\right)^{2}$$|64*y**2 + 160*y + 100||0|-1||0
# 2|$$\left(11 x - 11 y\right)^{2}$$|121*x**2 - 242*x*y + 121*y**2||0|-1||0
# 3|$$\left(12 x - 8\right)^{2}$$|144*x**2 - 192*x + 64||0|-1||0
# 4|$$\left(- 8 y - 1\right)^{2}$$|64*y**2 + 16*y + 1||0|-1||0
# 5|$$\left(- 6 x - 11 y\right)^{2}$$|36*x**2 + 132*x*y + 121*y**2||0|-1||0
# 6|$$\left(8 x + 2\right)^{2}$$|64*x**2 + 32*x + 4||0|-1||0
# 7|$$\left(11 - 15 y\right)^{2}$$|225*y**2 - 330*y + 121||0|-1||0
# 8|$$\left(9 x + 9 y\right)^{2}$$|81*x**2 + 162*x*y + 81*y**2||0|-1||0
# 9|$$\left(x \left(-10\right) - 2\right)^{2}$$|100*x**2 + 40*x + 4||0|-1||0

# %%
import random                                     #亂數 
import math                                       #math 內置數學函數
import numpy as np                                #數字矩陣
import sympy as sp                                #sympy 簡易別名 sp    
from sympy.parsing.sympy_parser import parse_expr #文字字串, 解釋成, Sympy 運算式
from IPython.display import Latex,HTML,Markdown                 #網頁顯示數學符號
import re
import lib
from lib import GetTE
sp.init_printing("mathjax")                       #sp.init_printing()  168 
def displayTable(NTE):
    display(Markdown(lib.NTE2TBL(NTE))) 
"""
整式的乘法公式完全平方公式 題型3  
"""   
def Get_PF2021_Expr(QN):
    x,y,z=sp.symbols('x y z')
    NTE=[]
    for Qid in range(0,QN):
        p,q=np.random.choice(range(-16,16),2)
        p=p if p!=0 else 1;q=q if q!=0 else 1
        Tidx=Qid % 3
        if Tidx==0:
            express_str=f"({p}*x+({q})) ** 2" 
            St=parse_expr(express_str, evaluate=False) 
            Stt=sp.latex(St)
        elif Tidx==1:
            St=(p+q*y)**2
            Stt=sp.latex(St)
        elif Tidx==2:
            St=(p*x+q*y)**2
            Stt=sp.latex(St)
        Val=sp.expand(St)
        TE=GetTE(Qid,Stt,Val)        
        NTE.append(TE)    
    return NTE

if __name__=="__main__":
    NTE=Get_PF2021_Expr(10)
    displayTable(NTE)
# Out:
# 號|題|值|答|檢查|題型|提示
# --|--|--|--|--|--|--
# 0|$$\left(9 x - 5\right)^{2}$$|81*x**2 - 90*x + 25||0|-1||0
# 1|$$\left(1 - 11 y\right)^{2}$$|121*y**2 - 22*y + 1||0|-1||0
# 2|$$\left(7 x + 11 y\right)^{2}$$|49*x**2 + 154*x*y + 121*y**2||0|-1||0
# 3|$$\left(4 + x \left(-16\right)\right)^{2}$$|256*x**2 - 128*x + 16||0|-1||0
# 4|$$\left(y + 4\right)^{2}$$|y**2 + 8*y + 16||0|-1||0
# 5|$$\left(- x - 2 y\right)^{2}$$|x**2 + 4*x*y + 4*y**2||0|-1||0
# 6|$$\left(x \left(-1\right) - 8\right)^{2}$$|x**2 + 16*x + 64||0|-1||0
# 7|$$\left(7 - 4 y\right)^{2}$$|16*y**2 - 56*y + 49||0|-1||0
# 8|$$\left(- 4 x + 10 y\right)^{2}$$|16*x**2 - 80*x*y + 100*y**2||0|-1||0
# 9|$$\left(1 x + 11\right)^{2}$$|x**2 + 22*x + 121||0|-1||0

# %%
def Put_PF2021_Expr(TE):
    ans=lib.Text2St(TE["Ans"])
    Val=TE["Val"]
    if parse_expr(ans).subs({x:7})==Val.subs({x:7}): 
        TE["OK"]=1; return True
    else: 
        return False
    
if __name__=="__main__":
    x,y,z=sp.symbols('x,y,z')
    NTE=Get_PF202_Expr(4)
    for i,TE in enumerate(NTE):
        St=TE["St"]
        Val=TE["Val"]
        print(f"第{i}題:")        
        display(Latex(f" $$ {St} $$ " ))
        print(TE["Tip"])
        TE["Ans"]=lib.Text2St(input("請作答:"))
        if Put_PF202_Expr(TE):                   #比對答案:
            print("答對!")                              #答對加一分
        else:                                      #不則
            display(Latex(f"答案錯誤, 標準答案: $ {Val} $"))
    displayTable(NTE)
# Out:
# 第0題:
#  $$ \left(x + 10\right) \left(x - 10\right) $$
# 請作答: x**2-100
# 答對!
# 第1題:
#  $$ \left(x - 6\right) \left(x - -6\right) $$
# 請作答: x**2-36
# 答對!
# 第2題:
#  $$ \left(x - 6\right) \left(x - -6\right) $$
# 請作答: 0
# 答案錯誤, 標準答案: $ x**2 - 36 $
# 第3題:
#  $$ \left(x + 2\right) \left(x - 2\right) $$
# 請作答: 0
# 答案錯誤, 標準答案: $ x**2 - 4 $
# <table><tr><td>St</td><td>Val</td><td>Ans</td><td>OK</td></tr><tr><td>$$\left(x + 10\right) \left(x - 10\right)$$</td><td>x**2 - 100</td><td>x**2-100</td><td>1</td></tr><tr><td>$$\left(x - 6\right) \left(x - -6\right)$$</td><td>x**2 - 36</td><td>x**2-36</td><td>1</td></tr><tr><td>$$\left(x - 6\right) \left(x - -6\right)$$</td><td>x**2 - 36</td><td>0</td><td>0</td></tr><tr><td>$$\left(x + 2\right) \left(x - 2\right)$$</td><td>x**2 - 4</td><td>0</td><td>0</td></tr></table>

# %%
print("end")
import re
ans ="-9x  ^2+25"
#ans = re.sub(r"(\d)x", r"\1*x", ans)
ans = re.sub(r"X", r"x", ans)
ans = re.sub(r"x[ ]*", r"x", ans)
ans = ans.replace(r"x^", r"x**")

ans
# Out:
# end
# '-9x**2+25'
