# %% [markdown]
# # 電腦數學符號運算

# %% [markdown]
# ### 第3節. 因式分解提公因式練習實作
# 安裝 Python 3.8.7
# - pip install numpy
# - pip install sympy
# - pip install jupyterlab
# - lib.py 自定義函數庫
#
# - 因式分解提公因式
#
# 第1題:
# $$x^5*(−5)y^4+x^4*(−25)y^5 $$
# 電腦標準答案: -5*x**4*y**4*(x + 5*y)
#
# 第2題:
# $$4x^1*y^3+x^1*(−5)y^2$$
# 電腦標準答案:  x*y**2*(4*y - 5)
#
#
# 第3題:
# $$6x^3*y^2+x^3*(−8)*y^1$$
# 電腦標準答案: 2*x**3*y*(3*y - 4)
#
# 第4題:
# $$ 3*x^1*y^3+3*x^0*y^5 $$
# 電腦標準答案: 3*y**3*(x + y**2)

# %% [markdown]
# 因式分解 提公因式
# 題型1：
# "{ab} * x**{p} * y**{q}  + {ac} * x**{u}*y**{v}  "
# s1=abxpyq, s2=acxuyv, s3=adxgyh, s1’= bxp-myq-n, s2’= cxu-myv-n, s3’= dxg-myh-n,
# s1 +s2 +s3=axmyn(s1’+ s2’+ s3’) (s1≠s2≠s3), s1 ,s2 ,s3亂序,s和s’的順序相同
# (|a|,|b|,|c|,|d|,|k|)<13 整數, -1<(p,q,u,v,g,h)<11整數, (a,b,c)≠0, m=min(p,u,g), n=min(q,v,h),
# (x,y)=(a至z內隨機字母) 或 (a至z內隨機字母 ± a至z內隨機字母) 或 (a至z內隨機字母 ± k), x≠y

# %%
import math                                       #math 內置數學函數
import numpy as np                                #數字矩陣
import re
import random                                     #亂數 
import sympy as sp                                #sympy 簡易別名 sp    
from sympy.parsing.sympy_parser import parse_expr #文字字串, 解釋成, Sympy 運算式
from IPython.display import Latex,HTML                 #網頁顯示數學符號
import lib
sp.init_printing("mathjax")                       #sp.init_printing()  168 

def displayTable(NTE):
    display(HTML(lib.NTE2HTML(NTE)))     
"""
因式分解 提公因式
"""
def Get_PF203_Expr(QizAmt):
    NTE=[]
    for i in range(0,QizAmt):
        a =  random.choice([-5,-4,-3,-2,-1,1,2,3,4,5])
        b =  random.choice([-5,-4,-3,-2,-1,1,2,3,4,5])
        c =  random.choice([-5,-4,-3,-2,-1,1,2,3,4,5])
        d =  random.choice([-5,-4,-3,-2,-1,1,2,3,4,5])
        ab=a*b
        ac=a*c
        ad=a*d
        p=random.choice([0,1,2,3,4,5])
        q=random.choice([0,1,2,3,4,5])
        u=random.choice([0,1,2,3,4,5])
        v=random.choice([0,1,2,3,4,5])
        
        express_str=f"{ab} * x**{p} * y**{q}  + {ac} * x**{u}*y**{v}  "  #題型 express_str ax+bx+c
        St=parse_expr(express_str, evaluate=False) #字串解釋為可運算式子 expression
        Val=sp.factor(St)
        
        TE={}
        TE["St"]=sp.latex(St)
        TE["ValLatex"]=sp.latex(Val)    
        TE["Val"]=Val
        TE["Ans"]="-"
        TE["OK"]="-"
        NTE.append(TE)    
    return NTE

x,y,z=sp.symbols('x,y,z')
NTE=Get_PF203_Expr(4)
displayTable(NTE)
# Out:
# <table><tr><td>St</td><td>Val</td><td>Ans</td><td>OK</td></tr><tr><td>$$4 x^{4} y^{5} + x^{2} \left(-20\right) y^{0}$$</td><td>4*x**2*(x**2*y**5 - 5)</td><td>-</td><td>-</td></tr><tr><td>$$x^{5} \left(-5\right) y^{2} + x^{1} \left(-15\right) y^{2}$$</td><td>-5*x*y**2*(x**4 + 3)</td><td>-</td><td>-</td></tr><tr><td>$$x^{4} \left(-10\right) y^{2} + 10 x^{0} y^{3}$$</td><td>-10*y**2*(x**4 - y)</td><td>-</td><td>-</td></tr><tr><td>$$4 x^{3} y^{3} + x^{1} \left(-4\right) y^{5}$$</td><td>4*x*y**3*(x - y)*(x + y)</td><td>-</td><td>-</td></tr></table>

# %%
"""程式二
因式分解 提公因式
"""
x,y,z=sp.symbols('x,y,z')
QizAmt=4
Mark=0
NTE=Get_PF203_Expr(QizAmt)
for i, TE in enumerate(NTE):
    St=TE["St"]
    Val=TE["Val"]
    ValLatex=TE["ValLatex"]
    print(f"第{i}題:")        
    display(Latex(f" $$ {St} $$ " ))
    #display(Latex(f"電腦標準答案: $ {ValLatex} $ ; {Val}"))
    ans=input("請作答:")  
    ans=lib.Text2St(ans)
    TE["Ans"]=ans
    if parse_expr(ans).subs({x:7})==Val.subs({x:7}):                   #比對答案:
        print("答對!")                              #答對加一分
        Mark+=1
        TE["OK"]=1
    else:                                      #不則
        TE["OK"]=0
        display(Latex(f"答案錯誤, 標準答案: $ {Val} $"))

print(f"總結: 共{QizAmt}題,得 {Mark} 分. ")  #總結得分

displayTable(NTE)
# Out:
# 第0題:
#  $$ x^{3} \left(-16\right) y^{5} + x^{0} \left(-20\right) y^{3} $$
# 請作答: 0
# 答案錯誤, 標準答案: $ -4*y**3*(4*x**3*y**2 + 5) $
# 第1題:
#  $$ 6 x^{5} y^{2} + 12 x^{3} y^{5} $$
# 請作答: 0
# 答案錯誤, 標準答案: $ 6*x**3*y**2*(x**2 + 2*y**3) $
# 第2題:
#  $$ x^{0} \left(-20\right) y^{3} + x^{0} \left(-16\right) y^{0} $$
# 請作答: 0
# 答案錯誤, 標準答案: $ -4*(5*y**3 + 4) $
# 第3題:
#  $$ 9 x^{4} y^{4} + 15 x^{2} y^{4} $$
# 請作答: 0
# 答案錯誤, 標準答案: $ 3*x**2*y**4*(3*x**2 + 5) $
# 總結: 共4題,得 0 分.
# <table><tr><td>St</td><td>Val</td><td>Ans</td><td>OK</td></tr><tr><td>$$x^{3} \left(-16\right) y^{5} + x^{0} \left(-20\right) y^{3}$$</td><td>-4*y**3*(4*x**3*y**2 + 5)</td><td>0</td><td>0</td></tr><tr><td>$$6 x^{5} y^{2} + 12 x^{3} y^{5}$$</td><td>6*x**3*y**2*(x**2 + 2*y**3)</td><td>0</td><td>0</td></tr><tr><td>$$x^{0} \left(-20\right) y^{3} + x^{0} \left(-16\right) y^{0}$$</td><td>-4*(5*y**3 + 4)</td><td>0</td><td>0</td></tr><tr><td>$$9 x^{4} y^{4} + 15 x^{2} y^{4}$$</td><td>3*x**2*y**4*(3*x**2 + 5)</td><td>0</td><td>0</td></tr></table>

# %%
print("end")
import re
ans ="-9x  ^2+25"
#ans = re.sub(r"(\d)x", r"\1*x", ans)
ans = re.sub(r"X", r"x", ans)
ans = re.sub(r"x[ ]*", r"x", ans)
ans = ans.replace(r"x^", r"x**")

ans = ans = re.sub(r"[)][(]", r")*(", re.sub(r"(\d)x", r"\1*x", ans))
ans = re.sub(r"X", r"x", ans)
ans = re.sub(r"x[ ]*", r"x", ans)
ans = ans.replace(r"x^", r"x**")

ans
# Out:
# end
# '-9x**2+25'

# %%
# Out:
# 第1題:
#  $$ x^{1} \left(-2\right) y^{5} + 4 x^{1} y^{2} $$
# 電腦標準答案: $ - 2 x y^{2} \left(y^{3} - 2\right) $ ; -2*x*y**2*(y**3 - 2)
# 第2題:
#  $$ 10 x^{2} y^{4} + 2 x^{0} y^{2} $$
# 電腦標準答案: $ 2 y^{2} \left(5 x^{2} y^{2} + 1\right) $ ; 2*y**2*(5*x**2*y**2 + 1)
# 第3題:
#  $$ 6 x^{5} y^{0} + x^{1} \left(-15\right) y^{2} $$
# 電腦標準答案: $ 3 x \left(2 x^{4} - 5 y^{2}\right) $ ; 3*x*(2*x**4 - 5*y**2)
# 第4題:
#  $$ x^{5} \left(-10\right) y^{1} + 6 x^{4} y^{5} $$
# 電腦標準答案: $ - 2 x^{4} y \left(5 x - 3 y^{4}\right) $ ; -2*x**4*y*(5*x - 3*y**4)
# <table><tr><td>St</td><td>Val</td><td>Ans</td><td>OK</td></tr><tr><td>$$x^{1} \left(-2\right) y^{5} + 4 x^{1} y^{2}$$</td><td>-2*x*y**2*(y**3 - 2)</td><td>-</td><td>-</td></tr><tr><td>$$10 x^{2} y^{4} + 2 x^{0} y^{2}$$</td><td>2*y**2*(5*x**2*y**2 + 1)</td><td>-</td><td>-</td></tr><tr><td>$$6 x^{5} y^{0} + x^{1} \left(-15\right) y^{2}$$</td><td>3*x*(2*x**4 - 5*y**2)</td><td>-</td><td>-</td></tr><tr><td>$$x^{5} \left(-10\right) y^{1} + 6 x^{4} y^{5}$$</td><td>-2*x**4*y*(5*x - 3*y**4)</td><td>-</td><td>-</td></tr></table>
