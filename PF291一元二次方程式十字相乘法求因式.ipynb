# %% [markdown]
# # 電腦數學符號運算

# %% [markdown]
# ### 第3節. 十字相乘法因式分解實作
# 安裝 Python 3.8.7
# - pip install numpy
# - pip install sympy
# - pip install jupyterlab
# - lib.py 自定義函數庫

# %%
import random                                     #亂數 
import math                                       #math 內置數學函數
import numpy as np                                #數字矩陣
import sympy as sp                                #sympy 簡易別名 sp    
from sympy.parsing.sympy_parser import parse_expr #文字字串, 解釋成, Sympy 運算式
from sympy.plotting import plot                   #繪圖表
from IPython.display import Latex,HTML                 #網頁顯示數學符號
import json                                       #JSON 結構化資料
import re
import lib
sp.init_printing("mathjax")                       #sp.init_printing()  168 
def displayTable(NTE):
    tablecontext="<table><tr><td>{}</td></tr>".format("</td><td>".join(_ for _ in ["Qiz","Val","Ans","OK"]))
    for row in NTE:
        St=row["St"]
        Val=row["Val"]
        Ans=row["Ans"]
        OK=row["OK"]
        tablecontext+=f"<tr><td>$${St}$$</td><td>{Val}</td><td>{Ans}</td><td>{OK}</td></tr>"
    tablecontext+="</table>"
    display(HTML(tablecontext)) 
"""
十字相乘法因式分解factor   x**2 + b*x + c
"""
def Get_PF291_Expr(QizAmt):
    sample_list0= list(range(-39,29))   # [-5,-4,-3,-2,-1,1,2,3,4,5]
    sample_list1= list(range(-39,29))
    sample_list1.remove(0)    # 非零數列
    NTE=[]
    for i in range(0,QizAmt):
        a = 1 
        p=random.choice([-5,-4,-3,-2,-1,1,2,3,4,5])
        q=random.choice([-5,-4,-3,-2,-1,1,2,3,4,5])
        b=p+q
        c=p*q
        express_str=f"{a}*x**2 + {b}*x +  {c} "  
        St=parse_expr(express_str, evaluate=False)     #字串解釋為可運算式子 expression
        Val=sp.factor(St)                              #因式分解,得出標準答案
        TE={}
        TE["St"]=sp.latex(St)
        TE["Val"]=Val     
        TE["Ans"]=""
        TE["OK"]=0
        NTE.append(TE)    
    return NTE

NTE=Get_PF291_Expr(10)
displayTable(NTE)
# Out:
# <table><tr><td>Qiz</td><td>Val</td><td>Ans</td><td>OK</td></tr><tr><td>$$1 x^{2} + 3 x + 2$$</td><td>(x + 1)*(x + 2)</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + 10 x + 25$$</td><td>(x + 5)**2</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + 1 x - 2$$</td><td>(x - 1)*(x + 2)</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + x \left(-4\right) + 3$$</td><td>(x - 3)*(x - 1)</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + x \left(-8\right) + 15$$</td><td>(x - 5)*(x - 3)</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + x \left(-8\right) + 16$$</td><td>(x - 4)**2</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + 2 x - 3$$</td><td>(x - 1)*(x + 3)</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + 0 x - 25$$</td><td>(x - 5)*(x + 5)</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + x \left(-1\right) - 20$$</td><td>(x - 5)*(x + 4)</td><td></td><td>0</td></tr><tr><td>$$1 x^{2} + 3 x - 10$$</td><td>(x - 2)*(x + 5)</td><td></td><td>0</td></tr></table>

# %%
"""
十字相乘法因式分解factor   x**2 + b*x + c
"""
x,y,z=sp.symbols('x,y,z')
NTE=Get_PF291_Expr(4)
for i,TE in enumerate(NTE):
    St=TE["St"]
    Val=TE["Val"]
    print(f"第{i}題:")        
    display(Latex(f" $$ {St} $$ " ))
    ans=lib.Text2St(input("請作答:")  )
    TE["Ans"]=ans
    if parse_expr(ans).subs({x:7})==Val.subs({x:7}):                   #比對答案:
        print("答對!")                              #答對加一分
        TE["OK"]=1
    else:                                      #不則
        TE["OK"]=0
        display(Latex(f"答案錯誤, 標準答案: $ {Val} $"))
    
displayTable(NTE)
# Out:
# 第0題:
#  $$ 1 x^{2} + x \left(-9\right) + 20 $$
# 請作答: 0
# 答案錯誤, 標準答案: $ (x - 5)*(x - 4) $
# 第1題:
#  $$ 1 x^{2} + 3 x - 4 $$
# 請作答: 0
# 答案錯誤, 標準答案: $ (x - 1)*(x + 4) $
# 第2題:
#  $$ 1 x^{2} + 2 x - 8 $$
# 請作答: 0
# 答案錯誤, 標準答案: $ (x - 2)*(x + 4) $
# 第3題:
#  $$ 1 x^{2} + 2 x - 15 $$
# 請作答: 0
# 答案錯誤, 標準答案: $ (x - 3)*(x + 5) $
# <table><tr><td>Qiz</td><td>Val</td><td>Ans</td><td>OK</td></tr><tr><td>$$1 x^{2} + x \left(-9\right) + 20$$</td><td>(x - 5)*(x - 4)</td><td>0</td><td>0</td></tr><tr><td>$$1 x^{2} + 3 x - 4$$</td><td>(x - 1)*(x + 4)</td><td>0</td><td>0</td></tr><tr><td>$$1 x^{2} + 2 x - 8$$</td><td>(x - 2)*(x + 4)</td><td>0</td><td>0</td></tr><tr><td>$$1 x^{2} + 2 x - 15$$</td><td>(x - 3)*(x + 5)</td><td>0</td><td>0</td></tr></table>

# %%
print("end")
import re
ans="(-2x+1)(x-5)"
ans = re.sub(r"[)][(]", r")*(", re.sub(r"(\d)x", r"\1*x", ans))
ans
# Out:
# end
# '(-2*x+1)*(x-5)'
