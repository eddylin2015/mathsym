# %% [markdown]
# # 對數運算基礎

# %% [markdown]
# ### 1.1 基本功能 (平方根,指数,自然対数,絶対値,三角函数)
#
# |平方根	|指数函数	|自然対数|	絶対値			|
# |---|---|---|---|
# |sqrt|	exp|	ln (=log)|	abs	|
#
#
# lg 10 = log10(10)=1
#
# ln E = log(E) =1
#
# $\log_{10}{100}$ = log(100,10)

# %% [markdown]
# a=Symbol("a")
# $e^{ln a}=a$

# %%
import sympy as sp
from sympy import I, pi, E
#from sympy.codegen.cfunctions import log10
from sympy.parsing.sympy_parser import parse_expr #文字字串, 解釋成, Sympy 運算式
from IPython.display import Latex,HTML,Markdown    
sp.init_printing("mathjax")                       #
print( sp.ln(E)   )
print( sp.log(E)  )
print( sp.log(100,10) )
print( parse_expr("ln(100)") )
print( parse_expr("log(100, 10)")== sp.log(100,10) )
expr=sp.log(7)-sp.log(2)
display(sp.logcombine(expr))
# Out:
# 1
# 1
# 2
# 2
# log(100)
# True
# log(7/2)
# log₁₀(14)

# %%
import sympy as sp
a=sp.Symbol("a")
sp.exp(sp.log(a))

# %% [markdown]
# $log e^2=2 log e=2$

# %%
log(E**2)
