# %% [markdown]
# # 對數運算基礎

# %% [markdown]
# ## 1.基本功能
#
# I, pi, E 常數
#
#
# |平方根	|指数函数	|自然対数|	絶対値			|
# |---|---|---|---|
# |sqrt|	exp|	ln (=log)|	abs	|
#
# E 表示自然數
#
# $ lg 100 = log(100,10)=10  $
#
# $ ln E = ln(E) = log(E) =1 $ 註明,log函数, 默認E為底
#
# $\log_{10}{100}$ = log(100,10)
#
# $E^{ln a}=a$

# %% [markdown]
# ### 電腦 ln x = log x

# %%
import sympy as sp
from sympy import I, pi, E
x,y,z = sp.symbols('x,y,z',positive=True)
a, n = sp.symbols('a n',real=True)

sp.ln(x)  # log(x)
# Out:
# log(x)

# %%
sp.log(E**x)
# Out:
# x

# %%
sp.ln(E**x)
# Out:
# x

# %%
sp.log(8,2)
# Out:
# 3

# %%
E**(sp.ln(a))
# Out:
# a

# %% [markdown]
# ## 2.log 運算
# log(x*y)=log(x)+log(y)
# log(x**n)=n* log(x)

# %% [markdown]
# ### 展開expand_log

# %%
sp.expand_log(sp.log(x*y))
# Out:
# log(x) + log(y)

# %%
sp.expand_log(sp.log(x/y))
# Out:
# log(x) - log(y)

# %%
sp.expand_log(sp.log(x**2))
# Out:
# 2*log(x)

# %%
sp.expand_log(sp.log(x**n))
# Out:
# n*log(x)

# %%
sp.expand_log(sp.log(z**2),force=True)
# Out:
# 2*log(z)

# %% [markdown]
# ### 簡化logcombine

# %%
exp=sp.log(x)+sp.log(y)
sp.logcombine(exp)
# Out:
# log(x*y)

# %%
# log(x**n)=n* log(x)
exp=n*sp.log(x)
sp.logcombine(exp)
# Out:
# log(x**n)

# %% [markdown]
# ### 輸入文字答案, 用 parse_expr 檢查對錯

# %%
import sympy as sp
from sympy import I, pi, E
from sympy.parsing.sympy_parser import parse_expr #文字字串, 解釋成, Sympy 運算式
answer="ln(100)"
print( parse_expr(answer)== sp.ln(100) )
answer="log(100, 10)"
print( parse_expr(answer)== sp.log(100,10) )
# Out:
# True
# True

# %% [markdown]
# ### 指数函数exp

# %%
import sympy as sp
a=sp.Symbol("a",real=True)
sp.exp(sp.log(a))
# Out:
# a

# %% [markdown]
# $log e^2=2 log e=2$

# %%
sp.log(E**a)
# Out:
# a

# %% [markdown]
# ## 3. 附加練習
# 練習 1
#
# random.randint（1,100）給出一個從1到100的隨機整數。 讓我們看看random.random（）會發生什麼。
#
#
# 練習 2 星星的亮度和等級
#
# 夜空中看到的星星的視在亮度L以m表示，並具有以下關係。
#
# $m=−2.5\log_{10}L+定数$
#
# 1級或6級哪個更亮？
#
# 提示:
#
# 假設1級和6級星的視在亮度分別為L1和L6。
#
# $1=−2.5 \log_{10} L1+定数,6=−2.5 \log_{10} L6+定数$
#
# 如果向兩側拉，
#
# $1−6=−2.5(\log_{10} L1−\log_{10} L6)$
#
# 換一種說法
#
# $\log_{10} (\frac{L1}{L6})=\frac{−5}{−2.5}=2$

# %% [markdown]
# ## 題目設計1

# %%
import sympy as sp
import random
from sympy import I, pi, E
from IPython.display import Latex,HTML,Markdown 
sp.init_printing("mathjax")                       #sp.init_printing()  168 
x,y,z = sp.symbols('x,y,z',positive=True)
a, n = sp.symbols('a n',real=True)
base_=[2,3,4,5,10]
val_=[2,3,4,5,sp.Rational(1,2),sp.Rational(1,3),sp.Rational(1,4),sp.Rational(1,5)]
for i in range(20):
    b=random.choice(base_)
    c=random.choice(val_)
    d=b**c
    St=r"\log_{%s}{%s}" %(b,sp.latex(d))
    Val=c
    SSt=sp.log(d,b)  # log(x)
    #display(SSt)   
    #display(sp.logcombine(SSt))
    display(Latex(f"$   {St} = {c} $" ))
    display(sp.expand_log(SSt))
# Out:
# $   \log_{10}{1000} = 3 $
# 3
# $   \log_{10}{\sqrt[5]{10}} = 1/5 $
# 1/5
# $   \log_{5}{\sqrt{5}} = 1/2 $
# 1/2
# $   \log_{2}{\sqrt[5]{2}} = 1/5 $
# 1/5
# $   \log_{5}{\sqrt[4]{5}} = 1/4 $
# 1/4
# $   \log_{4}{2^{\frac{2}{5}}} = 1/5 $
# 1/5
# $   \log_{4}{256} = 4 $
# 4
# $   \log_{5}{\sqrt[5]{5}} = 1/5 $
# 1/5
# $   \log_{10}{\sqrt[3]{10}} = 1/3 $
# 1/3
# $   \log_{10}{100} = 2 $
# 2
# $   \log_{3}{\sqrt[3]{3}} = 1/3 $
# 1/3
# $   \log_{3}{243} = 5 $
# 5
# $   \log_{10}{100000} = 5 $
# 5
# $   \log_{10}{10000} = 4 $
# 4
# $   \log_{2}{8} = 3 $
# 3
# $   \log_{3}{27} = 3 $
# 3
# $   \log_{3}{243} = 5 $
# 5
# $   \log_{4}{2^{\frac{2}{3}}} = 1/3 $
# 1/3
# $   \log_{2}{\sqrt[5]{2}} = 1/5 $
# 1/5
# $   \log_{5}{\sqrt[4]{5}} = 1/4 $
# 1/4

# %% [markdown]
# ## 題目設計2

# %%
import sympy as sp
import random
from sympy import I, pi, E
from IPython.display import Latex,HTML,Markdown 
sp.init_printing("mathjax")                       #sp.init_printing()  168 
x,y,z = sp.symbols('x,y,z',positive=True)
a, n = sp.symbols('a n',real=True)
base_=[2,3,4,5,10]
val_=[2,3,4,5,6,7,8]
for i in range(5):
    b=random.choice(base_)
    c1=random.choice([1,2,3])
    c2=random.choice(val_)
    c3=random.choice(val_)
    d=b**c1*c2*c3
    St=r"\log_{%s}{%s}" %(b,d)
    Val=c1+sp.log(c2,b)+sp.log(c3,b)
    display(Latex(f"$   {St} = {Val} $" ))
    SSt=sp.log(d,b)  # log(x)
    display(SSt)
    display(sp.expand_log(SSt,force=True))
    display(sp.logcombine(SSt,force=True))
# Out:
# $   \log_{4}{168} = 1 + log(6)/log(4) + log(7)/log(4) $
#     log(42)
# 1 + ───────
#      log(4)
#     log(42)
# 1 + ────────
#     2⋅log(2)
#        ⎛    1   ⎞
#        ⎜  ──────⎟
#        ⎜  log(4)⎟
# 1 + log⎝42      ⎠
# $   \log_{10}{120} = log(3)/log(10) + log(4)/log(10) + 1 $
#     log(12)
# 1 + ───────
#     log(10)
#     log(12)
# 1 + ───────
#     log(10)
#        ⎛     1   ⎞
#        ⎜  ───────⎟
#        ⎜  log(10)⎟
# 1 + log⎝12       ⎠
# $   \log_{3}{72} = log(8)/log(3) + 2 $
# log(8)
# ────── + 2
# log(3)
# 3⋅log(2)
# ──────── + 2
#  log(3)
#    ⎛   1   ⎞
#    ⎜ ──────⎟
#    ⎜ log(3)⎟
# log⎝8      ⎠ + 2
# $   \log_{2}{128} = 7 $
# 7
# 7
# 7
# $   \log_{3}{216} = log(2)/log(3) + log(4)/log(3) + 3 $
# log(8)
# ────── + 3
# log(3)
# 3⋅log(2)
# ──────── + 3
#  log(3)
#    ⎛   1   ⎞
#    ⎜ ──────⎟
#    ⎜ log(3)⎟
# log⎝8      ⎠ + 3

# %% [markdown]
# ## 題目設計3

# %% [markdown]
# ## 題目設計4

# %% [markdown]
# 結束.

# %% [markdown]
# ## X.其他參考:

# %% [markdown]
# ### 1.Plot

# %%
# Perquisites
import datetime
import numpy as np
import scipy as scp
import sympy as sp
from sympy.geometry import Point, Circle, Triangle, Segment, Line, RegularPolygon
import random
import math
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from IPython.display import Latex,HTML,Markdown                 #網頁顯示數學符號
from sympy.plotting import plot
from sympy import pi
#plot(expr1,(x, -5, 5)) 
u=sp.Symbol('u',positive=True)
expr1=(u, sp.sin(2*pi*u)+sp.cos(2*pi*u)+u)
expr2=(u, sp.log(u))
p=sp.plot_parametric(expr1,expr2, (u, -10,10 ), xlim =(0,10),ylim =(-10,10),line_color='blue',show=False)
p[1].line_color='red'
#p[2].line_color='green'
p.show()

# %% [markdown]
# ### 2. 平方根,指数,自然對数,絶対値,三角函数
# |平方根|指数函数|自然対数|絶対値|三角函数|逆三角函数|双曲線函数|
# |---|---|---|---|---|---|---|
# |sqrt|exp|ln(=log)|abs|sin|asin|sinh|
# |    |   |        |   |cos|acos|cosh|
# |    |   |        |   |tan|atan|tanh|
#
# 不要無意中設置$ \sqrt{x^ 2} = x$。 如果x是一個實數 $\sqrt{x^ 2}=|x|  $

# %%
import sympy as sp
from sympy import I, pi, E
from sympy.parsing.sympy_parser import parse_expr #文字字串, 解釋成, Sympy 運算式
from IPython.display import Latex,HTML,Markdown    
sp.init_printing("mathjax")                       #

x = sp.Symbol('x')
sp.sqrt(x**2)
# Out:
#    ____
#   ╱  2
# ╲╱  x

# %% [markdown]
# assume假設x為實數，

# %%
x=sp.Symbol('x', real=True)
sp.sqrt(x**2)
# Out:
# │x│

# %% [markdown]
# 滿足勾股定理的三個整數的示例。 $\sqrt{3^2+4^2}=5 $ 。

# %%
sp.sqrt(3**2 + 4**2)
# Out:
# 5

# %% [markdown]
# $exp(1)=e^1=e$ 。

# %%
sp.exp(1) - E
# Out:
# 0

# %% [markdown]
# ### 3. 自然對数

# %% [markdown]
# $e^{\ln a}=a$

# %%
a=sp.Symbol("a")
sp.exp(sp.log(a))
# Out:
# a

# %% [markdown]
# $\ln e^2=\log e^2=2 \log e= log(e^2) = 2$

# %%
sp.log(E**2)
# Out:
# 2

# %% [markdown]
# $\log_28 = log(8,2) $

# %%
sp.log(8,2)
# Out:
# 3

# %% [markdown]
# $\lg 100=\log_{10} 100 = log(100,10) $

# %%
from sympy.codegen.cfunctions import log10
log10(100)
# Out:
# 2
